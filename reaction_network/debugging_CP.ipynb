# %%
from fjss import FJSS2, FJSS3
import numpy as np
import time

from itertools import product
from collections import OrderedDict

from ortools.linear_solver import pywraplp
from ortools.sat.python import cp_model

from utils import get_m_value, parse_data
import pandas as pd

# %%
infinity = 1.0e6

# %%
def single_run(n_opt_selected=10, method="CP"):
    # load the data
    (
        n_opt,
        n_mach,
        operation_data,
        machine_data,
        para_lmin,
        para_lmax,
        para_p,
        para_h,
        para_w,
        para_delta,
        para_a,
        para_mach_capacity,
        big_m,
    ) = load_data()

    n_opt = n_opt_selected

    para_p_horizon = np.copy(para_p[:n_opt_selected, :])
    para_p_horizon[para_p_horizon == np.inf] = 0

    # para_h = np.empty((n_opt, n_mach), dtype=object)
    para_h_horizon = np.copy(para_h[:n_opt_selected, :])
    para_h_horizon[para_h_horizon == np.inf] = 0

    para_lmax_horizon = np.copy(para_lmax[:n_opt_selected, :n_opt_selected])
    para_lmax_horizon[para_lmax_horizon == np.inf] = 0

    horizon = (
        np.sum(para_p_horizon, axis=1)
        + np.sum(para_h_horizon, axis=1)
        + np.sum(para_lmax_horizon, axis=1)
    )
    horizon = int(np.sum(horizon)) + 1

    para_lmin[para_lmin == -np.inf] = -infinity
    para_lmin[para_lmin == np.inf] = infinity
    para_lmax[para_lmax == np.inf] = infinity
    para_lmax[para_lmax == -np.inf] = -infinity

    para_p[para_p == np.inf] = infinity
    para_p[para_p == -np.inf] = -infinity
    para_w[para_w == np.inf] = infinity
    para_w[para_w == -np.inf] = -infinity

    para_a[para_a == np.inf] = infinity
    para_a[para_a == -np.inf] = -infinity

    # =====================================================
    # convert all the numpy arrays with integers data type
    para_lmin = para_lmin.astype(int)
    para_lmax = para_lmax.astype(int)
    para_p = para_p.astype(int)
    para_w = para_w.astype(int)
    para_a = para_a.astype(int)
    para_delta = para_delta.astype(int)
    para_mach_capacity = para_mach_capacity.astype(int)

    para_lmin = para_lmin[:n_opt_selected, :n_opt_selected]
    para_lmax = para_lmax[:n_opt_selected, :n_opt_selected]

    para_p = para_p[:n_opt_selected, :]
    para_h = para_h[:n_opt_selected, :]
    para_w = para_w[:n_opt_selected, :]

    para_a = para_a[:n_opt_selected, :n_opt_selected, :]

    # machines
    machines = [str(i) for i in range(6)]
    # operations
    operations = [str(i) for i in range(n_opt_selected)]

    operations = operations[:n_opt_selected]
    machines = machines[:n_mach]

    # =====================================================
    if method == "CP":
        # time the running time for the CP model
        start_time = time.time()
        fjss2 = FJSS2(
            operations=operations,
            machines=machines,
            para_p=para_p,
            para_a=para_a,
            para_w=para_w,
            para_h=para_h,
            para_delta=para_delta,
            para_mach_capacity=para_mach_capacity,
            para_lmin=para_lmin,
            para_lmax=para_lmax,
            precedence=None,
            model_string=None,
            inf_cp=1.0e6,
            num_workers=4,
            verbose=True,
        )
        fjss2.build_model_ortools()
        fjss2.solve_ortools()
        # get the running time in seconds
        running_time = time.time() - start_time

        new_row = {
            "method": method,
            "n_opt": n_opt_selected,
            "n_mach": n_mach,
            "running_time_seconds": running_time,
            "num_constraints": 0,
            "makespan": fjss2.var_c_max,
        }
    elif method == "MILP":
        para_a = np.einsum("mij->ijm", para_a)
        # time the running time for the MILP model
        start_time = time.time()
        fjss3 = FJSS3(
            operations=operations,
            machines=machines,
            para_p=para_p,
            para_a=para_a,
            para_w=para_w,
            para_h=para_h,
            para_delta=para_delta,
            para_mach_capacity=para_mach_capacity,
            para_lmin=para_lmin,
            para_lmax=para_lmax,
            precedence=None,
            model_string=None,
            inf_milp=1.0e7,
            num_workers=4,
            verbose=True,
        )
        fjss3.solve_gurobi()
        running_time = time.time() - start_time
        new_row = {
            "method": method,
            "n_opt": n_opt_selected,
            "n_mach": n_mach,
            "running_time_seconds": running_time,
            "num_constraints": fjss3.solver.NumConstraints(),
            "makespan": fjss3.var_c_max,
        }
    else:
        raise ValueError("Invalid method!")

    return new_row


def load_data():
    n_opt, n_mach, operation_data, machine_data = parse_data(
        "fjss_cp_data/gfjsp_10_5_1.txt"
    )
    operation_data["0"]["h"] = 0
    operation_data["1"]["h"] = 0
    operation_data["2"]["h"] = 0
    operation_data["3"]["h"] = 20

    # define the parameters

    # minimum lag between the starting time of operation i and the ending time of operation j
    para_lmin = np.full((n_opt, n_opt), dtype=object, fill_value=-np.inf)
    # maximum lag between the starting time of operation i and the ending time of operation j
    para_lmax = np.full((n_opt, n_opt), dtype=object, fill_value=np.inf)

    # processing time of operation i in machine m
    # para_p = np.full((n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_p = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)

    # the shape of h in the original file is (n_machine) while the shape of para_h in the
    # paper is (n_opt, n_mach)
    # maximum holding time of operation i in machine m
    para_h = np.empty((n_opt, n_mach), dtype=object)
    # para_h = np.empty(n_mach, dtype=object)

    # mapping of operation i to machine m
    # 20 for the furnaces, 0 for Cutting, Pressing, and Forging
    # 0: Cutting; 1: Pressing; 2: Forging; 3: Furnace
    holding_time_dict = {
        "0": 0,
        "1": 0,
        "2": 0,
        "3": 20,
    }

    # weight of operation i in machine m
    # para_w = np.empty((n_opt, n_mach), dtype=object)
    para_w = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)

    # input/output delay time between two consecutive operations in mahcine m
    para_delta = np.empty((n_mach), dtype=object)

    # setup time of machine m when processing operation i before j
    # para_a = np.full((n_opt, n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_a = np.full((n_mach, n_opt, n_opt), dtype=object, fill_value=np.inf)

    # capacity of machine
    para_mach_capacity = np.empty((n_mach), dtype=object)
    for m in range(n_mach):
        # capacity of machine is a set of constant numbers
        para_mach_capacity[m] = machine_data[str(m)]["c"]

        # input/output delay time between two consecutive operations in mahcine m
        # delta(m): loading and unloading time of machine m (=1 for all machines)
        para_delta[m] = 1

        # set up time of machine m when processing operation i before j
        # a(i,j,m): setup time of machine m when processing operation i before j (aijm = -inf if there
        # is no setups)
        for idx_setup, setup_data in enumerate(machine_data[str(m)]["setup_data"][0]):
            para_a[m, int(setup_data[0]), int(setup_data[1])] = setup_data[2]

        # maximum holding time of operation i in machine m
        para_h[:, m] = holding_time_dict[str(machine_data[str(m)]["t"])]

    # lag time
    for i in range(n_opt):
        for idx_lag, lag_data in enumerate(operation_data[str(i)]["lag"]):
            # minimum lag between the starting time of operation i and the ending time of operation j
            para_lmin[i, int(lag_data[0])] = lag_data[1]
            # maximum lag between the starting time of operation i and the ending time of operation j
            para_lmax[i, int(lag_data[0])] = lag_data[2]

        for idx_pw, pw_data in enumerate(operation_data[str(i)]["pw"]):
            # operation_data[str(1)]["pw"]
            # # the shape of para_p in the original file is the transpose of the shape of para_p
            # para_p[i, int(pw_data[0])] = pw_data[1]
            # # the shape of para_w in the original file is the transpose of the shape of para_w
            # para_w[i, int(pw_data[0])] = pw_data[2]

            # the shape of para_p in the original file is the transpose of the shape of para_p
            para_p[int(pw_data[0]), i] = pw_data[1]
            # the shape of para_w in the original file is the transpose of the shape of para_w
            para_w[int(pw_data[0]), i] = pw_data[2]

    # reformat the shape of para_p and para_w
    para_p = para_p.T
    para_w = para_w.T

    # # reshape the shape of para_a
    # para_a = np.einsum("mij->ijm", para_a)

    # the big M value
    big_m = get_m_value(
        para_p=para_p, para_h=para_h, para_lmin=para_lmin, para_a=para_a
    )

    return (
        n_opt,
        n_mach,
        operation_data,
        machine_data,
        para_lmin,
        para_lmax,
        para_p,
        para_h,
        para_w,
        para_delta,
        para_a,
        para_mach_capacity,
        big_m,
    )

# %%
n_opt_selected = 50
method = "CP"

# %%
    (
        n_opt,
        n_mach,
        operation_data,
        machine_data,
        para_lmin,
        para_lmax,
        para_p,
        para_h,
        para_w,
        para_delta,
        para_a,
        para_mach_capacity,
        big_m,
    ) = load_data()

    n_opt = n_opt_selected

    para_p_horizon = np.copy(para_p[:n_opt_selected, :])
    para_p_horizon[para_p_horizon == np.inf] = 0

    # para_h = np.empty((n_opt, n_mach), dtype=object)
    para_h_horizon = np.copy(para_h[:n_opt_selected, :])
    para_h_horizon[para_h_horizon == np.inf] = 0

    para_lmax_horizon = np.copy(para_lmax[:n_opt_selected, :n_opt_selected])
    para_lmax_horizon[para_lmax_horizon == np.inf] = 0

    horizon = (
        np.sum(para_p_horizon, axis=1)
        + np.sum(para_h_horizon, axis=1)
        + np.sum(para_lmax_horizon, axis=1)
    )
    horizon = int(np.sum(horizon)) + 1

    para_lmin[para_lmin == -np.inf] = -infinity
    para_lmin[para_lmin == np.inf] = infinity
    para_lmax[para_lmax == np.inf] = infinity
    para_lmax[para_lmax == -np.inf] = -infinity

    para_p[para_p == np.inf] = infinity
    para_p[para_p == -np.inf] = -infinity
    para_w[para_w == np.inf] = infinity
    para_w[para_w == -np.inf] = -infinity

    para_a[para_a == np.inf] = infinity
    para_a[para_a == -np.inf] = -infinity

    # =====================================================
    # convert all the numpy arrays with integers data type
    para_lmin = para_lmin.astype(int)
    para_lmax = para_lmax.astype(int)
    para_p = para_p.astype(int)
    para_w = para_w.astype(int)
    para_a = para_a.astype(int)
    para_delta = para_delta.astype(int)
    para_mach_capacity = para_mach_capacity.astype(int)

    para_lmin = para_lmin[:n_opt_selected, :n_opt_selected]
    para_lmax = para_lmax[:n_opt_selected, :n_opt_selected]

    para_p = para_p[:n_opt_selected, :]
    para_h = para_h[:n_opt_selected, :]
    para_w = para_w[:n_opt_selected, :]

    para_a = para_a[:n_opt_selected, :n_opt_selected, :]

    # machines
    machines = [str(i) for i in range(6)]
    # operations
    operations = [str(i) for i in range(n_opt_selected)]

    operations = operations[:n_opt_selected]
    machines = machines[:n_mach]

    # =====================================================
    if method == "CP":
        # time the running time for the CP model
        start_time = time.time()
        fjss2 = FJSS2(
            operations=operations,
            machines=machines,
            para_p=para_p,
            para_a=para_a,
            para_w=para_w,
            para_h=para_h,
            para_delta=para_delta,
            para_mach_capacity=para_mach_capacity,
            para_lmin=para_lmin,
            para_lmax=para_lmax,
            precedence=None,
            model_string=None,
            inf_cp=1.0e6,
            num_workers=16,
            verbose=True,
        )
        fjss2.build_model_ortools()
        fjss2_solution = fjss2.solve_ortools()
        # get the running time in seconds
        running_time = time.time() - start_time

        new_row = {
            "method": method,
            "n_opt": n_opt_selected,
            "n_mach": n_mach,
            "running_time_seconds": running_time,
            "num_constraints": 0,
            "makespan": fjss2.var_c_max,
        }
    elif method == "MILP":
        para_a = np.einsum("mij->ijm", para_a)
        # time the running time for the MILP model
        start_time = time.time()
        fjss3 = FJSS3(
            operations=operations,
            machines=machines,
            para_p=para_p,
            para_a=para_a,
            para_w=para_w,
            para_h=para_h,
            para_delta=para_delta,
            para_mach_capacity=para_mach_capacity,
            para_lmin=para_lmin,
            para_lmax=para_lmax,
            precedence=None,
            model_string=None,
            inf_milp=1.0e7,
            num_workers=16,
            verbose=True,
        )
        fjss3.solve_gurobi()
        running_time = time.time() - start_time
        new_row = {
            "method": method,
            "n_opt": n_opt_selected,
            "n_mach": n_mach,
            "running_time_seconds": running_time,
            "num_constraints": fjss3.solver.NumConstraints(),
            "makespan": fjss3.var_c_max,
        }
    else:
        raise ValueError("Invalid method!")
# Out:
# Starting CP-SAT solver v9.8.3296
# Parameters: log_search_progress: true num_search_workers: 16
#
# Initial optimization model '': (model_fingerprint: 0xcf42e113342f4bbe)
# #Variables: 16'925'201 (#ints: 1 in objective)
#   - 10'178'700 Booleans in [0,1]
#   - 29'501 in [0,11195]
#   - 6'717'000 in [0,1000000]
# #kBoolAnd: 14'700 (#enforced: 14'700) (#literals: 44'100)
# #kBoolOr: 44'100 (#enforced: 44'100) (#literals: 58'800)
# #kIntProd: 3'358'500
# #kLinMax: 29'400 (#expressions: 58'800)
# #kLinear1: 20'151'000 (#enforced: 20'151'000)
# #kLinear2: 6'839'550 (#enforced: 6'834'600) (#complex_domain: 14'700)
# #kLinear3: 58'800 (#enforced: 58'800)
# #kLinearN: 67'320 (#terms: 3'359'600)
#
# Starting presolve at 9.09s
#   1.66e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.94e+02s  0.00e+00d  [PresolveToFixPoint] #num_loops=22 #num_dual_strengthening=5
#   7.86e-01s  0.00e+00d  [ExtractEncodingFromLinear] #potential_supersets=33'569
# [Symmetry] Problem too large. Skipping. You can use symmetry_level:3 or more to force it.
# [SAT presolve] num removable Booleans: 2313924 / 10083852
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:10088748 literals:23538984 vars:10082922 one_side_vars:856 simple_definition:10081224 singleton_clauses:0
# [SAT presolve] [1.75216s] clauses:10088748 literals:23538984 vars:10082922 one_side_vars:856 simple_definition:10081224 singleton_clauses:0
# [SAT presolve] [6.33158s] clauses:3147608 literals:7348068 vars:3150254 one_side_vars:5578 simple_definition:3144588 singleton_clauses:0
#   5.53e+01s  1.15e+00d *[Probe] #probed=167 #fixed_bools=7 #equiv=5'574'672 #new_binary_clauses=1'212
#   5.24e+00s  0.00e+00d  [MaxClique]
#   1.27e+01s  0.00e+00d  [DetectDominanceRelations]
#   1.60e+02s  0.00e+00d  [PresolveToFixPoint] #num_loops=7 #num_dual_strengthening=6
#   3.06e+01s  0.00e+00d  [DetectDuplicateConstraints] #duplicates=11'152'732
#   7.74e+00s  0.00e+00d  [DetectDifferentVariables] #different=28
#   1.42e+00s  3.01e-03d  [DetectDominatedLinearConstraints] #relevant_constraints=92'502 #num_inclusions=29'415
#   5.55e+00s  3.77e-02d  [ProcessSetPPC] #relevant_constraints=3'180'957 #num_inclusions=2'096'907
#   9.45e-01s  0.00e+00d  [FindAlmostIdenticalLinearConstraints]
#   8.39e-01s  3.68e-03d  [FindBigHorizontalLinearOverlap] #linears=33'543
#   1.83e+00s  2.20e-01d  [FindBigVerticalLinearOverlap] #blocks=1 #saved_nz=45
#   2.28e+00s  1.58e-02d  [MergeClauses]
#   1.53e+01s  0.00e+00d  [DetectDominanceRelations]
#   1.86e+02s  0.00e+00d  [PresolveToFixPoint] #num_loops=24 #num_dual_strengthening=9
#   1.51e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.47e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=1 #num_dual_strengthening=1
# [Symmetry] Problem too large. Skipping. You can use symmetry_level:3 or more to force it.
# [SAT presolve] num removable Booleans: 154 / 2112112
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:3025495 literals:7052136 vars:2085996 one_side_vars:3708 simple_definition:1611738 singleton_clauses:0
# [SAT presolve] [0.575198s] clauses:3025495 literals:7052136 vars:2085996 one_side_vars:3708 simple_definition:1611738 singleton_clauses:0
# [SAT presolve] [0.757708s] clauses:3025061 literals:7051142 vars:2085590 one_side_vars:3708 simple_definition:1611360 singleton_clauses:0
#   3.70e+01s  1.02e+00d *[Probe] #probed=1'408 #fixed_bools=34 #equiv=315'089 #new_binary_clauses=4'220
#   5.51e+00s  0.00e+00d  [MaxClique]
#   1.59e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.72e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=2 #num_dual_strengthening=1
#   1.17e+01s  0.00e+00d  [DetectDuplicateConstraints] #duplicates=606'725 #without_enforcements=1'492
#   7.77e+00s  0.00e+00d  [DetectDifferentVariables] #different=76 #cliques=4 #size=12
#   1.44e+00s  2.70e-03d  [DetectDominatedLinearConstraints] #relevant_constraints=74'296 #num_inclusions=21'096 #num_redundant=264
#   5.55e+00s  3.59e-02d  [ProcessSetPPC] #relevant_constraints=3'026'776 #num_inclusions=1'994'612
#   8.59e-01s  0.00e+00d  [FindAlmostIdenticalLinearConstraints]
#   8.94e-01s  3.57e-03d  [FindBigHorizontalLinearOverlap] #linears=33'543
#   1.69e+00s  2.03e-01d  [FindBigVerticalLinearOverlap] #blocks=1 #saved_nz=45
#   2.49e+00s  1.50e-02d  [MergeClauses]
#   1.49e+01s  0.00e+00d  [DetectDominanceRelations]
#   5.84e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=3 #num_dual_strengthening=2
#   1.52e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.38e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=1 #num_dual_strengthening=1
# [Symmetry] Problem too large. Skipping. You can use symmetry_level:3 or more to force it.
# [SAT presolve] num removable Booleans: 646 / 1796193
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:2996359 literals:6993738 vars:1766827 one_side_vars:3664 simple_definition:998738 singleton_clauses:0
# [SAT presolve] [0.52914s] clauses:2996359 literals:6993738 vars:1766827 one_side_vars:3664 simple_definition:998738 singleton_clauses:0
# [SAT presolve] [0.669911s] clauses:2994421 literals:6989862 vars:1766181 one_side_vars:3676 simple_definition:998726 singleton_clauses:0
#   3.54e+01s  1.02e+00d *[Probe] #probed=1'468 #equiv=512 #new_binary_clauses=3'615
#   5.31e+00s  0.00e+00d  [MaxClique] Merged 2027930(4290211 literals) into 2027261(4288873 literals) at_most_ones.
#   1.51e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.36e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=1 #num_dual_strengthening=1
#   1.05e+01s  0.00e+00d  [DetectDuplicateConstraints] #duplicates=1'280
#   1.01e+00s  0.00e+00d  [DetectDifferentVariables]
#   1.58e+00s  2.69e-03d  [DetectDominatedLinearConstraints] #relevant_constraints=73'726 #num_inclusions=20'550
#   5.77e+00s  3.59e-02d  [ProcessSetPPC] #relevant_constraints=3'025'039 #num_inclusions=1'993'337
#   1.03e+00s  0.00e+00d  [FindAlmostIdenticalLinearConstraints]
#   8.42e-01s  3.57e-03d  [FindBigHorizontalLinearOverlap] #linears=33'543
#   1.54e+00s  2.03e-01d  [FindBigVerticalLinearOverlap]
#   2.67e+00s  1.50e-02d  [MergeClauses]
#   1.51e+01s  0.00e+00d  [DetectDominanceRelations]
#   4.30e+01s  0.00e+00d  [PresolveToFixPoint] #num_loops=1 #num_dual_strengthening=1
#   1.95e+00s  0.00e+00d  [ExpandObjective] #entries=136 #tight_variables=68 #tight_constraints=23
#
# Presolve summary:
#   - 11134470 affine relations were detected.
#   - rule 'TODO dual: add implied bound' was applied 15'834'552 times.
#   - rule 'TODO dual: make linear1 equiv' was applied 9'858 times.
#   - rule 'TODO dual: only one blocking constraint?' was applied 20'860'580 times.
#   - rule 'TODO dual: only one blocking enforced constraint?' was applied 16'851'596 times.
#   - rule 'TODO dual: only one unspecified blocking constraint?' was applied 22 times.
#   - rule 'TODO duplicate: identical constraint with different enforcements' was applied 1'492 times.
#   - rule 'TODO lin_max: linear expression above max.' was applied 457'536 times.
#   - rule 'TODO linear2: contains a Boolean.' was applied 6'748'196 times.
#   - rule 'affine: new relation' was applied 11'134'470 times.
#   - rule 'all_diff: inferred from x != y constraints' was applied 4 times.
#   - rule 'at_most_one: empty or all false' was applied 637 times.
#   - rule 'at_most_one: removed literals' was applied 37'645 times.
#   - rule 'at_most_one: size one' was applied 207 times.
#   - rule 'at_most_one: transformed into max clique.' was applied 1 time.
#   - rule 'bool_and: always false' was applied 12'180 times.
#   - rule 'bool_and: non-reified.' was applied 23'064 times.
#   - rule 'bool_and: x => x' was applied 5'231'108 times.
#   - rule 'bool_or: always true' was applied 49'063 times.
#   - rule 'bool_or: implications' was applied 58'111 times.
#   - rule 'bool_or: only one literal' was applied 131'700 times.
#   - rule 'bool_or: removed enforcement literal' was applied 3'374'098 times.
#   - rule 'deductions: 29146415 stored' was applied 1 time.
#   - rule 'dual: enforced equivalence' was applied 4'914'700 times.
#   - rule 'dual: equivalent Boolean in near-duplicate constraints' was applied 11'401 times.
#   - rule 'dual: fix variable' was applied 22'665 times.
#   - rule 'dual: make encoding equiv' was applied 400 times.
#   - rule 'dual: reduced domain' was applied 736'236 times.
#   - rule 'duplicate: merged rhs of linear constraint' was applied 201 times.
#   - rule 'duplicate: removed constraint' was applied 11'760'737 times.
#   - rule 'enforcement: false literal' was applied 112'132 times.
#   - rule 'enforcement: literal not used' was applied 1'702 times.
#   - rule 'enforcement: true literal' was applied 98'334 times.
#   - rule 'exactly_one: removed literals' was applied 50 times.
#   - rule 'exactly_one: size one' was applied 28 times.
#   - rule 'incompatible linear: add implication' was applied 75'852 times.
#   - rule 'int_prod: constant product' was applied 2'308'804 times.
#   - rule 'int_prod: expanded product with Boolean var' was applied 736'236 times.
#   - rule 'int_prod: linearize product by constant.' was applied 313'460 times.
#   - rule 'int_prod: removed constant expressions.' was applied 2'622'264 times.
#   - rule 'lin_max: canonicalize target using gcd' was applied 4'608 times.
#   - rule 'lin_max: converted to equality' was applied 9'072 times.
#   - rule 'lin_max: divising by gcd' was applied 4'608 times.
#   - rule 'lin_max: removed exprs' was applied 9'072 times.
#   - rule 'lin_max: target domain reduced' was applied 60'144 times.
#   - rule 'lin_max: unused affine target' was applied 264 times.
#   - rule 'linear inclusion: redundant containing constraint' was applied 264 times.
#   - rule 'linear matrix: common vertical rectangle' was applied 2 times.
#   - rule 'linear1: transformed to implication' was applied 6'768 times.
#   - rule 'linear2: implied ax + by = cte has only one solution' was applied 3'374'098 times.
#   - rule 'linear: always true' was applied 166'164 times.
#   - rule 'linear: empty' was applied 32'323 times.
#   - rule 'linear: fixed or dup variables' was applied 2'851'252 times.
#   - rule 'linear: infeasible' was applied 91'916 times.
#   - rule 'linear: negative clause' was applied 3'372'900 times.
#   - rule 'linear: positive at most one' was applied 33'585 times.
#   - rule 'linear: positive clause' was applied 1'198 times.
#   - rule 'linear: positive equal one' was applied 50 times.
#   - rule 'linear: reduced variable domains' was applied 413'667 times.
#   - rule 'linear: reduced variable domains in derived constraint' was applied 22 times.
#   - rule 'linear: remapped using affine relations' was applied 653'694 times.
#   - rule 'linear: simplified rhs' was applied 55'399'887 times.
#   - rule 'linear: variable substitution 0' was applied 1 time.
#   - rule 'presolve: 4862145 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 3 times.
#   - rule 'setppc: exactly_one included in linear' was applied 44 times.
#   - rule 'setppc: reduced linear coefficients' was applied 44 times.
#   - rule 'setppc: removed dominated constraints' was applied 471 times.
#   - rule 'variables: add encoding constraint' was applied 4'598'292 times.
#   - rule 'variables: canonicalize affine domain' was applied 4'608 times.
#   - rule 'variables: detect fully reified value encoding' was applied 934 times.
#   - rule 'variables: detect half reified value encoding' was applied 7'509'041 times.
#   - rule 'variables: only used in encoding' was applied 2'299'146 times.
#   - rule 'variables: removable enforcement literal' was applied 1'282 times.
#
# Presolved optimization model '': (model_fingerprint: 0xfb36eeca89bd9407)
# #Variables: 3'235'403 (#ints: 1 in objective)
#   - 1'788'123 Booleans in [0,1]
#   - 1 in [-10609,10745]
#   - 1'427'142 in [0,5000]
#   - 144 in [0,10178]
#   - 192 in [0,10183]
#   - 288 in [0,10408]
#   - 384 in [0,10413]
#   - 576 in [0,10421]
#   - 768 in [0,10426]
#   - 1 in [0,10497]
#   - 144 in [0,10548]
#   - 192 in [0,10553]
#   - 732 in [0,10568]
#   - 564 in [0,10573]
#   - 144 in [0,10584]
#   - 192 in [0,10589]
#   - 864 in [0,10614]
#   - 1'152 in [0,10619]
#   - 2 in [0,10677]
#   - 576 in [0,10726]
#   - 768 in [0,10731]
#   - 1'104 in [0,10735]
#   - 840 in [0,10740]
#   - 144 in [0,10755]
#   - 144 in [0,10759]
#   - 192 in [0,10760]
#   - 192 in [0,10764]
#   - 1 in [0,10768]
#   - 732 in [0,10805]
#   - 564 in [0,10810]
#   - 192 in [0,10811]
#   - 132 in [0,10816]
#   - 1 in [0,10824]
#   - 192 in [0,10884]
#   - 132 in [0,10889]
#   - 144 in [0,10897]
#   - 192 in [0,10902]
#   - 1 in [0,10939]
#   - 384 in [0,10941]
#   - 264 in [0,10946]
#   - 192 in [0,10947]
#   - 132 in [0,10952]
#   - 192 in [0,10976]
#   - 132 in [0,10981]
#   - 192 in [0,11095]
#   - 132 in [0,11100]
#   - 192 in [0,11118]
#   - 132 in [0,11123]
#   - 5'544 in [0,11195]
#   - 1 in [5,10502]
#   - 2 in [5,10682]
#   - 1 in [5,10773]
#   - 1 in [5,10829]
#   - 1 in [5,10944]
#   - 2 in [194,10962]
#   - 2 in [194,11133]
#   - 1 in [199,10967]
#   - 1 in [199,11138]
#   - 2 in [246,11014]
#   - 2 in [246,11185]
#   - 1 in [256,11024]
#   - 4 in [279,10956]
#   - 2 in [284,10961]
#   - 2 in [286,11110]
#   - 1 in [291,11115]
#   - 2 in [303,11071]
#   - 1 in [313,11081]
#   - 2 in [329,10826]
#   - 1 in [334,10831]
#   - 4 in [352,11029]
#   - 2 in [360,11128]
#   - 2 in [361,11185]
#   - 2 in [362,11039]
#   - 1 in [370,11138]
#   - 2 in [415,10912]
#   - 2 in [417,11185]
#   - 1 in [425,10922]
#   - 4 in [430,11107]
#   - 2 in [440,11117]
#   - 2 in [506,11003]
#   - 4 in [508,11185]
#   - 1 in [516,11013]
#   - 2 in [597,11094]
#   - 1 in [607,11104]
#   - 2 in [688,11185]
#   - 1 in [698,11195]
# #kAllDiff: 4
# #kAtMostOne: 32'355 (#literals: 299'061)
# #kBoolAnd: 1'063'875 (#enforced: 1'063'875) (#literals: 3'058'682)
# #kBoolOr: 998'846 (#literals: 2'998'712)
# #kExactlyOne: 22 (#literals: 66)
# #kLinMax: 20'064 (#expressions: 40'128)
# #kLinear1: 3'680'827 (#enforced: 3'680'827)
# #kLinear2: 716'327 (#enforced: 716'207)
# #kLinear3: 40'063 (#enforced: 40'044)
# #kLinearN: 33'543 (#terms: 713'571)
#
# Preloading model.
# #Bound 1522.11s best:inf   next:[698,11195] initial_domain
# [Symmetry] Problem too large. Skipping. You can use symmetry_level:3 or more to force it.
# #Model 1531.14s var:3235403/3235403 constraints:6585926/6585926
#
# Starting search at 1533.54s with 16 workers.
# 11 full problem subsolvers: [default_lp, lb_tree_search, max_lp, no_lp, objective_lb_search, objective_shaving_search_no_lp, probing, pseudo_costs, quick_restart, quick_restart_no_lp, reduced_costs]
# 4 first solution subsolvers: [fj_long_default, fj_short_default, fs_random, fs_random_quick_restart]
# 9 incomplete subsolvers: [feasibility_pump, graph_arc_lns, graph_cst_lns, graph_dec_lns, graph_var_lns, rins/rens, rnd_cst_lns, rnd_var_lns, violation_ls]
# 3 helper subsolvers: [neighborhood_helper, synchronization_agent, update_gap_integral]
# #Model 1578.82s var:3235361/3235403 constraints:6585146/6585926
# #Model 1600.90s var:3235359/3235403 constraints:6585142/6585926
# #1     1604.79s best:9207  next:[698,9206] quick_restart_no_lp (fixed_bools=45/3928838)
# #2     1608.24s best:9205  next:[698,9204] quick_restart_no_lp (fixed_bools=584109/3928851)
# #3     1613.48s best:9204  next:[698,9203] violation_ls(batch:1 #solutions_imported:1 #lin_moves:0 #lin_evals:22 #gen_moves:13 #gen_evals:2 #comp_moves:9 #backtracks:2 #weight_updates:0)
# #Bound 1618.75s best:9204  next:[699,9203] objective_shaving_search_no_lp (vars=67961 csts=131252)
# #Model 1619.53s var:2780574/3235403 constraints:5653237/6585926
# #4     1624.55s best:9203  next:[699,9202] quick_restart_no_lp (fixed_bools=587006/3928868)
# #5     1627.95s best:9202  next:[699,9201] quick_restart_no_lp (fixed_bools=587306/3928886)
# #Model 1632.88s var:2779874/3235403 constraints:5651810/6585926
# #6     1638.58s best:8826  next:[699,8825] quick_restart_no_lp (fixed_bools=587604/3928903)
# #Model 1645.07s var:2779407/3235403 constraints:5650858/6585926
# #Bound 1655.23s best:8826  next:[700,8825] objective_lb_search
# #Model 1657.17s var:2692175/3235403 constraints:5473010/6585926
# #7     1670.43s best:8825  next:[700,8824] violation_ls(batch:2 #solutions_imported:2 #lin_moves:251 #lin_evals:662 #gen_moves:1'296 #gen_evals:2'208 #comp_moves:9 #backtracks:2 #weight_updates:1'033)
# #8     1671.30s best:862   next:[700,861]  objective_lb_search (fixed_bools=699646/3928841)
# #Model 1682.43s var:841424/3235403 constraints:1700444/6585926
# #Model 1688.56s var:841388/3235403 constraints:1700374/6585926
# #Model 1694.45s var:841365/3235403 constraints:1700328/6585926
# #Model 1703.18s var:841354/3235403 constraints:1700306/6585926
# #9     1709.14s best:852   next:[700,851]  quick_restart_no_lp (fixed_bools=3076300/3928909)
# #Model 1710.34s var:841318/3235403 constraints:1700234/6585926
# #Model 1716.44s var:838793/3235403 constraints:1695114/6585926
# #Model 1722.45s var:830426/3235403 constraints:1678391/6585926
# #10    1725.30s best:851   next:[700,850]  quick_restart_no_lp (fixed_bools=3087881/3928916)
# #Model 1728.75s var:830412/3235403 constraints:1678373/6585926
# #11    1729.98s best:815   next:[700,814]  quick_restart_no_lp (fixed_bools=3088189/3928921)
# #Model 1734.96s var:830166/3235403 constraints:1677883/6585926
# #12    1740.01s best:814   next:[700,813]  quick_restart_no_lp (fixed_bools=3099676/3928921)
# #Model 1741.71s var:821147/3235403 constraints:1659618/6585926
# #13    1742.81s best:813   next:[700,812]  quick_restart_no_lp (fixed_bools=3099984/3928921)
# #14    1745.65s best:812   next:[700,811]  quick_restart_no_lp (fixed_bools=3100322/3928923)
# #Model 1750.56s var:820864/3235403 constraints:1659061/6585926
# #Model 1757.00s var:820343/3235403 constraints:1658024/6585926
# #Bound 1757.20s best:812   next:[701,811]  objective_shaving_search_no_lp (vars=67760 csts=131209)
# #Model 1763.52s var:820334/3235403 constraints:1658022/6585926
# #15    1765.98s best:811   next:[701,810]  quick_restart_no_lp (fixed_bools=3100648/3928928)
# #Model 1769.89s var:820316/3235403 constraints:1657999/6585926
# #Model 1776.49s var:820064/3235403 constraints:1657496/6585926
# #Bound 1780.59s best:811   next:[702,810]  objective_lb_search
# #Model 1782.93s var:820045/3235403 constraints:1657481/6585926
# #Model 1789.51s var:820029/3235403 constraints:1657470/6585926
# #Model 1796.13s var:820017/3235403 constraints:1657463/6585926
# #Model 1802.39s var:820000/3235403 constraints:1657446/6585926
# #Model 1811.48s var:819983/3235403 constraints:1657436/6585926
# #Model 1818.15s var:819966/3235403 constraints:1657433/6585926
# #Model 1824.79s var:819962/3235403 constraints:1657425/6585926
# #16    1828.14s best:810   next:[702,809]  quick_restart_no_lp (fixed_bools=3101005/3928947)
# #Model 1831.18s var:819955/3235403 constraints:1657421/6585926
# #Model 1837.47s var:819683/3235403 constraints:1656871/6585926
# #Model 1843.91s var:819681/3235403 constraints:1656871/6585926
# #Model 1850.35s var:819669/3235403 constraints:1656855/6585926
# #Model 1857.11s var:819663/3235403 constraints:1656847/6585926
# #17    1863.74s best:809   next:[702,808]  quick_restart_no_lp (fixed_bools=3101364/3928955)
# #Model 1866.15s var:819659/3235403 constraints:1656847/6585926
# #Model 1872.64s var:819410/3235403 constraints:1656356/6585926
# #Model 1879.29s var:819390/3235403 constraints:1656320/6585926
# #Bound 1879.57s best:809   next:[703,808]  objective_shaving_search_no_lp (vars=65638 csts=128817)
# #Model 1885.71s var:819382/3235403 constraints:1656311/6585926
# #18    1886.28s best:808   next:[703,807]  quick_restart_no_lp (fixed_bools=3101706/3928958)
# #19    1890.81s best:709   next:[703,708]  objective_lb_search (fixed_bools=3100940/3928845)
# #Model 1892.02s var:819371/3235403 constraints:1656303/6585926
# #Model 1897.82s var:776949/3235403 constraints:1575022/6585926
# #20    1899.73s best:708   next:[703,707]  quick_restart_no_lp (fixed_bools=3163693/3928958)
# #Model 1903.31s var:766429/3235403 constraints:1553982/6585926
# #Model 1908.88s var:764541/3235403 constraints:1549951/6585926
# #Model 1914.19s var:764523/3235403 constraints:1549915/6585926
# #Model 1920.84s var:764504/3235403 constraints:1549879/6585926
# #Model 1925.51s var:764488/3235403 constraints:1549848/6585926
# #Model 1930.45s var:764482/3235403 constraints:1549836/6585926
# #Model 1935.49s var:753993/3235403 constraints:1528858/6585926
# #Model 1940.41s var:753972/3235403 constraints:1528828/6585926
# #Model 1945.78s var:753958/3235403 constraints:1528813/6585926
# #Model 1950.49s var:743399/3235403 constraints:1507695/6585926
# #Bound 1954.70s best:708   next:[704,707]  objective_shaving_search_no_lp (vars=65888 csts=129417)
# #Model 1955.00s var:743388/3235403 constraints:1507685/6585926
# #Bound 1955.39s best:708   next:[705,707]  objective_lb_search
# #Model 1960.86s var:743381/3235403 constraints:1507672/6585926
# #21    1962.25s best:707   next:[705,706]  default_lp (fixed_bools=3166043/3928837)
# #Model 1965.32s var:743339/3235403 constraints:1507593/6585926
# #Model 1969.93s var:743012/3235403 constraints:1506952/6585926
# #Model 1974.47s var:743006/3235403 constraints:1506940/6585926
# #Model 1979.20s var:743003/3235403 constraints:1506934/6585926
# #Model 1983.33s var:742992/3235403 constraints:1506912/6585926
# #Model 1987.88s var:742983/3235403 constraints:1506894/6585926
# #Model 1992.49s var:742970/3235403 constraints:1506874/6585926
# #Model 1998.34s var:742964/3235403 constraints:1506872/6585926
# #Model 2006.88s var:742963/3235403 constraints:1506870/6585926
# #Bound 2011.66s best:707   next:[706,706]  objective_lb_search
# #Model 2013.30s var:742954/3235403 constraints:1506860/6585926
# #Model 2019.78s var:742780/3235403 constraints:1506470/6585926
# #Model 2026.48s var:742778/3235403 constraints:1506470/6585926
# #Model 2033.00s var:741482/3235403 constraints:1504404/6585926
# #Done  2039.26s quick_restart_no_lp
# #Done  2039.26s no_lp
# #Done  2039.35s quick_restart
# #Done  2039.38s probing
# #Model 2039.63s var:728802/3235403 constraints:1479001/6585926
# #Model 2045.09s var:276102/3235403 constraints:563004/6585926
#
# Task timing                                 n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#                       'default_lp':         1 [   8.44m,    8.44m]    8.44m   0.00ns    8.44m         1 [  59.07s,   59.07s]   59.07s   0.00ns   59.07s
#                 'feasibility_pump':        18 [371.55ms,   26.30s]    2.05s    5.91s   36.94s        17 [ 68.61ms, 429.06ms] 197.56ms 135.18ms    3.36s
#                  'fj_long_default':        17 [242.15ms,    5.04s] 585.67ms    1.11s    9.96s        17 [ 24.14ms, 138.74ms]  63.79ms  37.02ms    1.08s
#                 'fj_short_default':        27 [264.75ms,    6.76s] 560.44ms    1.22s   15.13s        27 [ 15.97ms,  96.55ms]  54.48ms  20.46ms    1.47s
#                        'fs_random':         1 [   1.22m,    1.22m]    1.22m   0.00ns    1.22m         1 [   7.04s,    7.04s]    7.04s   0.00ns    7.04s
#          'fs_random_quick_restart':         1 [   1.19m,    1.19m]    1.19m   0.00ns    1.19m         1 [   8.91s,    8.91s]    8.91s   0.00ns    8.91s
#                    'graph_arc_lns':         9 [   6.88s,    1.08m]   28.70s   19.01s    4.31m         3 [100.10ms, 107.51ms] 103.29ms   3.11ms 309.87ms
#                    'graph_cst_lns':         8 [   6.19s,   32.59s]   17.66s    8.09s    2.35m         1 [ 10.00ns,  10.00ns]  10.00ns   0.00ns  10.00ns
#                    'graph_dec_lns':         8 [  18.46s,   31.05s]   24.30s    4.81s    3.24m         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                    'graph_var_lns':         9 [   9.54s,    1.04m]   31.98s   18.42s    4.80m         3 [  1.66ms, 102.24ms]  42.02ms  43.39ms 126.05ms
#                   'lb_tree_search':         1 [   8.48m,    8.48m]    8.48m   0.00ns    8.48m         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                           'max_lp':         1 [   8.46m,    8.46m]    8.46m   0.00ns    8.46m         1 [   2.37m,    2.37m]    2.37m   0.00ns    2.37m
#                            'no_lp':         1 [   8.43m,    8.43m]    8.43m   0.00ns    8.43m         1 [  50.91s,   50.91s]   50.91s   0.00ns   50.91s
#              'objective_lb_search':         1 [   8.44m,    8.44m]    8.44m   0.00ns    8.44m         1 [   1.49m,    1.49m]    1.49m   0.00ns    1.49m
#   'objective_shaving_search_no_lp':         8 [  16.51s,    1.67m]   57.03s   27.99s    7.60m         5 [  7.11ms,    1.98s]    1.29s 751.37ms    6.46s
#                          'probing':         1 [   8.43m,    8.43m]    8.43m   0.00ns    8.43m         1 [  22.63s,   22.63s]   22.63s   0.00ns   22.63s
#                     'pseudo_costs':         1 [  11.30m,   11.30m]   11.30m   0.00ns   11.30m         1 [ 49.95us,  49.95us]  49.95us   0.00ns  49.95us
#                    'quick_restart':         1 [   8.43m,    8.43m]    8.43m   0.00ns    8.43m         1 [   1.28m,    1.28m]    1.28m   0.00ns    1.28m
#              'quick_restart_no_lp':         1 [   8.43m,    8.43m]    8.43m   0.00ns    8.43m         1 [   1.09m,    1.09m]    1.09m   0.00ns    1.09m
#                    'reduced_costs':         1 [  14.33m,   14.33m]   14.33m   0.00ns   14.33m         1 [ 49.95us,  49.95us]  49.95us   0.00ns  49.95us
#                        'rins/rens':         9 [492.36ms,   22.79s]   12.25s    5.47s    1.84m         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                      'rnd_cst_lns':         9 [   9.63s,   30.87s]   20.63s    5.78s    3.09m         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                      'rnd_var_lns':         9 [   5.60s,   28.33s]   14.05s    7.13s    2.11m         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                     'violation_ls':         9 [   3.30s,    6.95s]    4.68s    1.33s   42.09s         9 [  9.91ms,   10.94s]    5.69s    3.22s   51.18s
#
# Search stats                      Bools  Conflicts  Branches  Restarts   BoolPropag  IntegerPropag
#                'default_lp':  3'928'837      1'311   240'021     1'134  166'402'124    401'731'878
#                 'fs_random':  3'928'837        158     6'112     1'135   54'738'751     28'944'318
#   'fs_random_quick_restart':  3'928'837         82     6'470     1'134   51'527'765     24'650'204
#            'lb_tree_search':  3'948'901         42     1'130     1'130    8'630'139      9'770'690
#                    'max_lp':  3'948'901         51     1'274     1'132   12'301'755     13'422'319
#                     'no_lp':  3'928'837      3'060   242'647     1'147  218'865'549    461'236'850
#       'objective_lb_search':  3'928'846      3'999   192'633     1'143  508'242'945    589'343'107
#                   'probing':  3'929'900        821     3'114     3'409  113'069'934     36'612'295
#              'pseudo_costs':  3'948'901         42     1'130     1'130    8'630'139      9'770'690
#             'quick_restart':  3'928'858        810   158'029     1'249  167'386'006    331'869'178
#       'quick_restart_no_lp':  3'928'979      2'511   428'159     1'572  501'664'822    580'105'943
#             'reduced_costs':  3'948'901         42     1'130     1'130    8'630'139      9'770'690
#
# Lp stats                      Component  Iterations  AddedCuts  OPTIMAL  DUAL_F.  DUAL_U.
#                'default_lp':          1     135'921        172    2'233      117       14
#                 'fs_random':          1      19'820          0      880        6        0
#   'fs_random_quick_restart':          1      44'691          0    1'201       20        0
#            'lb_tree_search':          1      52'463          0        0        1        0
#                    'max_lp':          1      23'430          0        0      154        0
#       'objective_lb_search':          1     373'617        630    5'587      348       59
#                   'probing':          1      61'093        498    7'489      476       37
#              'pseudo_costs':          1           5     20'124        3        1        0
#             'quick_restart':          1     289'826      2'562   15'978      208       14
#             'reduced_costs':          1           5     20'124        3        1        0
#
# Lp dimension                                                                              Final dimension of first component
#                'default_lp':          9316 rows, 20138 columns, 33772 entries with magnitude in [1.000000e+00, 1.000000e+00]
#                 'fs_random':         10062 rows, 20138 columns, 35920 entries with magnitude in [1.000000e+00, 1.000000e+00]
#   'fs_random_quick_restart':         10392 rows, 20138 columns, 37519 entries with magnitude in [1.000000e+00, 1.000000e+00]
#            'lb_tree_search':  6785179 rows, 3275531 columns, 18581504 entries with magnitude in [9.142439e-05, 1.000000e+00]
#                    'max_lp':  6785179 rows, 3275531 columns, 18581504 entries with magnitude in [9.142439e-05, 1.000000e+00]
#       'objective_lb_search':         10136 rows, 20138 columns, 36961 entries with magnitude in [1.000000e+00, 1.000000e+00]
#                   'probing':          6921 rows, 20138 columns, 25680 entries with magnitude in [1.000000e+00, 1.000000e+00]
#              'pseudo_costs':         1000 rows, 3275531 columns, 3000 entries with magnitude in [1.000000e+00, 1.000000e+00]
#             'quick_restart':          8822 rows, 20138 columns, 32400 entries with magnitude in [1.000000e+00, 1.000000e+00]
#             'reduced_costs':         1000 rows, 3275531 columns, 3000 entries with magnitude in [1.000000e+00, 1.000000e+00]
#
# Lp debug                      CutPropag  CutEqPropag  Adjust  Overflow        Bad  BadScaling
#                'default_lp':        302          256       0         0    135'037           0
#                 'fs_random':          0            0       0         0          0           0
#   'fs_random_quick_restart':         15            0       0         0          0           0
#            'lb_tree_search':          0            0       0         0          0           0
#                    'max_lp':          0            0       0         0          0           0
#       'objective_lb_search':        620          311       0         0    105'505           0
#                   'probing':      5'146          632       0         0  8'239'875           0
#              'pseudo_costs':          0            0       0         0          0           0
#             'quick_restart':      2'159          536       1         0    630'029           0
#             'reduced_costs':          0            0       0         0          0           0
#
# Lp pool                       Constraints  Updates    Simplif   Merged  Shortened  Split  Strenghtened      Cuts/Call
#                'default_lp':       20'375   18'766     48'473        0      3'057      0             0     172/18'000
#                 'fs_random':       20'203      404          0        0          0      0             0            0/0
#   'fs_random_quick_restart':       20'203      623          0        0          0      0             0            0/0
#            'lb_tree_search':    6'785'179        0          0  713'577         93      0     3'630'517            0/0
#                    'max_lp':    6'785'179        0          0  713'577         93      0     3'630'517            0/0
#       'objective_lb_search':       20'833   88'487     46'657        0      3'281      0             0      630/7'666
#                   'probing':       20'701  173'050  1'298'271        0      3'776      0            18     498/10'918
#              'pseudo_costs':    6'805'303        0  2'203'364  713'577         93      0     5'833'930  20'124/20'124
#             'quick_restart':       22'764   74'611    474'679        1      4'911      0             4   2'562/53'325
#             'reduced_costs':    6'805'303        0  2'203'364  713'577         93      0     5'833'930  20'124/20'124
#
# Lp Cut          default_lp  quick_restart  reduced_costs  pseudo_costs  probing  objective_lb_search
#         CG_FF:           -          1'050              -             -        -                  324
#          CG_K:           1             19              -             -        2                    2
#          CG_R:         157            866              -             -      116                  124
#        Clique:           -              -             10            10        -                    -
#            IB:           -              -             50            50        -                    -
#        LinMax:           -              -         20'064        20'064        -                    -
#      MIR_2_FF:           -              2              -             -        -                    -
#       MIR_2_R:           -              4              -             -        -                    5
#       MIR_3_R:           -              1              -             -        -                    1
#   ZERO_HALF_K:           -              1              -             -        -                    -
#   ZERO_HALF_R:          14            619              -             -      380                  174
#
# LNS stats           Improv/Calls  Closed  Difficulty  TimeLimit
#   'graph_arc_lns':           6/6     50%        0.61       0.10
#   'graph_cst_lns':           1/2    100%        0.81       0.10
#   'graph_dec_lns':           8/8    100%        0.98       0.10
#   'graph_var_lns':           8/8     88%        0.96       0.10
#       'rins/rens':           8/8    100%        0.98       0.10
#     'rnd_cst_lns':           5/5    100%        0.94       0.10
#     'rnd_var_lns':           4/4    100%        0.91       0.10
#
# LS stats               Batches  Restarts  LinMoves  GenMoves  CompoundMoves  WeightUpdates
#    'fj_long_default':       17         1   170'000         0              0              0
#   'fj_short_default':       27         1         0   269'988        269'640              0
#       'violation_ls':        9         0    36'467     5'880          1'142          4'820
#
# Solutions (21)            Num     Rank
#            'default_lp':    1  [21,21]
#   'objective_lb_search':    2   [8,19]
#   'quick_restart_no_lp':   16   [1,20]
#          'violation_ls':    2    [3,7]
#
# Objective bounds                     Num
#                   'initial_domain':    1
#              'objective_lb_search':    4
#   'objective_shaving_search_no_lp':    4
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':     27      116        0       26
#         'lp solutions':      1        1        0        1
#                 'pump':      8        8
#
# Improving bounds shared          Num
#             'default_lp':     17'369
#                 'max_lp':          1
#                  'no_lp':     86'342
#    'objective_lb_search':     82'387
#                'probing':  1'904'782
#          'quick_restart':     46'949
#    'quick_restart_no_lp':  2'689'792
#                 'random':      1'322
#   'random_quick_restart':         15
#
# Clauses shared                Num
#             'default_lp':      95
#                 'max_lp':       1
#                  'no_lp':     581
#    'objective_lb_search':      42
#                'probing':  12'514
#          'quick_restart':   1'075
#    'quick_restart_no_lp':  20'934
#                 'random':      66
#   'random_quick_restart':       6
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: 707
# best_bound: 707
# integers: 1447280
# booleans: 3928837
# conflicts: 82
# branches: 6470
# propagations: 51527765
# integer_propagations: 24650204
# restarts: 1134
# lp_iterations: 44691
# walltime: 2435.03
# usertime: 2435.03
# deterministic_time: 590.088
# gap_integral: 422.078
# solution_fingerprint: 0xeba4ed89eb3f7d44
#
# Optimal Schedule Length: 707.0

# %%
solver = fjss2._solver
model = fjss2._model

# %%
var_y = fjss2.var_y

# for y in solver.Value(var_y):
#     if  y== 1:
#         print(y)

[y for y in var_y.flatten() if solver.Value(y) == 1]
# Out:
# [y_0_0(0..1),
#  y_1_4(0..1),
#  y_2_1(0..1),
#  y_3_4(0..1),
#  y_4_2(0..1),
#  y_5_4(0..1),
#  y_6_2(0..1),
#  y_7_4(0..1),
#  y_8_2(0..1),
#  y_9_0(0..1),
#  y_10_5(0..1),
#  y_11_1(0..1),
#  y_12_5(0..1),
#  y_13_2(0..1),
#  y_14_5(0..1),
#  y_15_2(0..1),
#  y_16_5(0..1),
#  y_17_2(0..1),
#  y_18_5(0..1),
#  y_19_2(0..1),
#  y_20_0(0..1),
#  y_21_4(0..1),
#  y_22_1(0..1),
#  y_23_4(0..1),
#  y_24_2(0..1),
#  y_25_4(0..1),
#  y_26_2(0..1),
#  y_27_4(0..1),
#  y_28_2(0..1),
#  y_29_0(0..1),
#  y_30_3(0..1),
#  y_31_1(0..1),
#  y_32_3(0..1),
#  y_33_2(0..1),
#  y_34_0(0..1),
#  y_35_3(0..1),
#  y_36_1(0..1),
#  y_37_3(0..1),
#  y_38_2(0..1),
#  y_39_3(0..1),
#  y_40_2(0..1),
#  y_41_3(0..1),
#  y_42_2(0..1),
#  y_43_3(0..1),
#  y_44_2(0..1),
#  y_45_0(0..1),
#  y_46_3(0..1),
#  y_47_1(0..1),
#  y_48_3(0..1),
#  y_49_2(0..1)]

# %%
# start time of operation i in machine m
var_s = fjss2.var_s

[solver.Value(s) for s in var_s]
# Out:
# [50,
#  72,
#  371,
#  386,
#  479,
#  496,
#  565,
#  578,
#  646,
#  0,
#  5,
#  333,
#  338,
#  424,
#  434,
#  515,
#  525,
#  606,
#  616,
#  697,
#  40,
#  100,
#  399,
#  414,
#  490,
#  500,
#  577,
#  587,
#  659,
#  30,
#  35,
#  321,
#  328,
#  399,
#  10,
#  27,
#  238,
#  253,
#  317,
#  327,
#  374,
#  393,
#  454,
#  470,
#  540,
#  20,
#  34,
#  248,
#  256,
#  328]

# %%
# completion time of operation i in machine m
var_c = fjss2.var_c

[solver.Value(c) for c in var_s]
# Out:
# [50,
#  72,
#  371,
#  386,
#  479,
#  496,
#  565,
#  578,
#  646,
#  0,
#  5,
#  333,
#  338,
#  424,
#  434,
#  515,
#  525,
#  606,
#  616,
#  697,
#  40,
#  100,
#  399,
#  414,
#  490,
#  500,
#  577,
#  587,
#  659,
#  30,
#  35,
#  321,
#  328,
#  399,
#  10,
#  27,
#  238,
#  253,
#  317,
#  327,
#  374,
#  393,
#  454,
#  470,
#  540,
#  20,
#  34,
#  248,
#  256,
#  328]

# %%
# var_u = fjss2.var_u

fjss2.var_u
# Out:
# array([[[u_0_0_0(0..1000000), u_0_0_1(0..1000000), u_0_0_2(0..1000000),
#          ..., u_0_0_11192(0..1000000), u_0_0_11193(0..1000000),
#          u_0_0_11194(0..1000000)],
#         [u_0_1_0(0..1000000), u_0_1_1(0..1000000), u_0_1_2(0..1000000),
#          ..., u_0_1_11192(0..1000000), u_0_1_11193(0..1000000),
#          u_0_1_11194(0..1000000)],
#         [u_0_2_0(0..1000000), u_0_2_1(0..1000000), u_0_2_2(0..1000000),
#          ..., u_0_2_11192(0..1000000), u_0_2_11193(0..1000000),
#          u_0_2_11194(0..1000000)],
#         [u_0_3_0(0..1000000), u_0_3_1(0..1000000), u_0_3_2(0..1000000),
#          ..., u_0_3_11192(0..1000000), u_0_3_11193(0..1000000),
#          u_0_3_11194(0..1000000)],
#         [u_0_4_0(0..1000000), u_0_4_1(0..1000000), u_0_4_2(0..1000000),
#          ..., u_0_4_11192(0..1000000), u_0_4_11193(0..1000000),
#          u_0_4_11194(0..1000000)],
#         [u_0_5_0(0..1000000), u_0_5_1(0..1000000), u_0_5_2(0..1000000),
#          ..., u_0_5_11192(0..1000000), u_0_5_11193(0..1000000),
#          u_0_5_11194(0..1000000)]],
#
#        [[u_1_0_0(0..1000000), u_1_0_1(0..1000000), u_1_0_2(0..1000000),
#          ..., u_1_0_11192(0..1000000), u_1_0_11193(0..1000000),
#          u_1_0_11194(0..1000000)],
#         [u_1_1_0(0..1000000), u_1_1_1(0..1000000), u_1_1_2(0..1000000),
#          ..., u_1_1_11192(0..1000000), u_1_1_11193(0..1000000),
#          u_1_1_11194(0..1000000)],
#         [u_1_2_0(0..1000000), u_1_2_1(0..1000000), u_1_2_2(0..1000000),
#          ..., u_1_2_11192(0..1000000), u_1_2_11193(0..1000000),
#          u_1_2_11194(0..1000000)],
#         [u_1_3_0(0..1000000), u_1_3_1(0..1000000), u_1_3_2(0..1000000),
#          ..., u_1_3_11192(0..1000000), u_1_3_11193(0..1000000),
#          u_1_3_11194(0..1000000)],
#         [u_1_4_0(0..1000000), u_1_4_1(0..1000000), u_1_4_2(0..1000000),
#          ..., u_1_4_11192(0..1000000), u_1_4_11193(0..1000000),
#          u_1_4_11194(0..1000000)],
#         [u_1_5_0(0..1000000), u_1_5_1(0..1000000), u_1_5_2(0..1000000),
#          ..., u_1_5_11192(0..1000000), u_1_5_11193(0..1000000),
#          u_1_5_11194(0..1000000)]],
#
#        [[u_2_0_0(0..1000000), u_2_0_1(0..1000000), u_2_0_2(0..1000000),
#          ..., u_2_0_11192(0..1000000), u_2_0_11193(0..1000000),
#          u_2_0_11194(0..1000000)],
#         [u_2_1_0(0..1000000), u_2_1_1(0..1000000), u_2_1_2(0..1000000),
#          ..., u_2_1_11192(0..1000000), u_2_1_11193(0..1000000),
#          u_2_1_11194(0..1000000)],
#         [u_2_2_0(0..1000000), u_2_2_1(0..1000000), u_2_2_2(0..1000000),
#          ..., u_2_2_11192(0..1000000), u_2_2_11193(0..1000000),
#          u_2_2_11194(0..1000000)],
#         [u_2_3_0(0..1000000), u_2_3_1(0..1000000), u_2_3_2(0..1000000),
#          ..., u_2_3_11192(0..1000000), u_2_3_11193(0..1000000),
#          u_2_3_11194(0..1000000)],
#         [u_2_4_0(0..1000000), u_2_4_1(0..1000000), u_2_4_2(0..1000000),
#          ..., u_2_4_11192(0..1000000), u_2_4_11193(0..1000000),
#          u_2_4_11194(0..1000000)],
#         [u_2_5_0(0..1000000), u_2_5_1(0..1000000), u_2_5_2(0..1000000),
#          ..., u_2_5_11192(0..1000000), u_2_5_11193(0..1000000),
#          u_2_5_11194(0..1000000)]],
#
#        ...,
#
#        [[u_47_0_0(0..1000000), u_47_0_1(0..1000000),
#          u_47_0_2(0..1000000), ..., u_47_0_11192(0..1000000),
#          u_47_0_11193(0..1000000), u_47_0_11194(0..1000000)],
#         [u_47_1_0(0..1000000), u_47_1_1(0..1000000),
#          u_47_1_2(0..1000000), ..., u_47_1_11192(0..1000000),
#          u_47_1_11193(0..1000000), u_47_1_11194(0..1000000)],
#         [u_47_2_0(0..1000000), u_47_2_1(0..1000000),
#          u_47_2_2(0..1000000), ..., u_47_2_11192(0..1000000),
#          u_47_2_11193(0..1000000), u_47_2_11194(0..1000000)],
#         [u_47_3_0(0..1000000), u_47_3_1(0..1000000),
#          u_47_3_2(0..1000000), ..., u_47_3_11192(0..1000000),
#          u_47_3_11193(0..1000000), u_47_3_11194(0..1000000)],
#         [u_47_4_0(0..1000000), u_47_4_1(0..1000000),
#          u_47_4_2(0..1000000), ..., u_47_4_11192(0..1000000),
#          u_47_4_11193(0..1000000), u_47_4_11194(0..1000000)],
#         [u_47_5_0(0..1000000), u_47_5_1(0..1000000),
#          u_47_5_2(0..1000000), ..., u_47_5_11192(0..1000000),
#          u_47_5_11193(0..1000000), u_47_5_11194(0..1000000)]],
#
#        [[u_48_0_0(0..1000000), u_48_0_1(0..1000000),
#          u_48_0_2(0..1000000), ..., u_48_0_11192(0..1000000),
#          u_48_0_11193(0..1000000), u_48_0_11194(0..1000000)],
#         [u_48_1_0(0..1000000), u_48_1_1(0..1000000),
#          u_48_1_2(0..1000000), ..., u_48_1_11192(0..1000000),
#          u_48_1_11193(0..1000000), u_48_1_11194(0..1000000)],
#         [u_48_2_0(0..1000000), u_48_2_1(0..1000000),
#          u_48_2_2(0..1000000), ..., u_48_2_11192(0..1000000),
#          u_48_2_11193(0..1000000), u_48_2_11194(0..1000000)],
#         [u_48_3_0(0..1000000), u_48_3_1(0..1000000),
#          u_48_3_2(0..1000000), ..., u_48_3_11192(0..1000000),
#          u_48_3_11193(0..1000000), u_48_3_11194(0..1000000)],
#         [u_48_4_0(0..1000000), u_48_4_1(0..1000000),
#          u_48_4_2(0..1000000), ..., u_48_4_11192(0..1000000),
#          u_48_4_11193(0..1000000), u_48_4_11194(0..1000000)],
#         [u_48_5_0(0..1000000), u_48_5_1(0..1000000),
#          u_48_5_2(0..1000000), ..., u_48_5_11192(0..1000000),
#          u_48_5_11193(0..1000000), u_48_5_11194(0..1000000)]],
#
#        [[u_49_0_0(0..1000000), u_49_0_1(0..1000000),
#          u_49_0_2(0..1000000), ..., u_49_0_11192(0..1000000),
#          u_49_0_11193(0..1000000), u_49_0_11194(0..1000000)],
#         [u_49_1_0(0..1000000), u_49_1_1(0..1000000),
#          u_49_1_2(0..1000000), ..., u_49_1_11192(0..1000000),
#          u_49_1_11193(0..1000000), u_49_1_11194(0..1000000)],
#         [u_49_2_0(0..1000000), u_49_2_1(0..1000000),
#          u_49_2_2(0..1000000), ..., u_49_2_11192(0..1000000),
#          u_49_2_11193(0..1000000), u_49_2_11194(0..1000000)],
#         [u_49_3_0(0..1000000), u_49_3_1(0..1000000),
#          u_49_3_2(0..1000000), ..., u_49_3_11192(0..1000000),
#          u_49_3_11193(0..1000000), u_49_3_11194(0..1000000)],
#         [u_49_4_0(0..1000000), u_49_4_1(0..1000000),
#          u_49_4_2(0..1000000), ..., u_49_4_11192(0..1000000),
#          u_49_4_11193(0..1000000), u_49_4_11194(0..1000000)],
#         [u_49_5_0(0..1000000), u_49_5_1(0..1000000),
#          u_49_5_2(0..1000000), ..., u_49_5_11192(0..1000000),
#          u_49_5_11193(0..1000000), u_49_5_11194(0..1000000)]]],
#       dtype=object)

# %% [markdown]
# ## Checking the constraints

# %%
# # check eq. (22)

# for i, j, m in product(range(n_opt_selected), range(n_opt_selected), range(n_mach)):
#     if i != j:
#         if solver.Value(var_y[i, m]) == 1 and solver.Value(var_y[j, m]) == 1:
#             bool_left = (
#                 solver.Value(var_s[j]) >= solver.Value(var_c[i]) + para_a[m, i, j]
#             )
#             bool_right = (
#                 solver.Value(var_s[i]) >= solver.Value(var_c[j]) + para_a[m, j, i]
#             )
#             assert bool_left or bool_right

# # check eq. (23)

# for i, j, m in product(range(n_opt_selected), range(n_opt_selected), range(n_mach)):
#     if i != j:
#         if solver.Value(var_y[i, m]) == 1 and solver.Value(var_y[j, m]) == 1:
#             bool_left = (
#                 solver.Value(var_s[j])
#                 >= solver.Value(var_s[i])
#                 + max(
#                     [
#                         0,
#                         solver.Value(var_c[i])
#                         - solver.Value(var_s[i])
#                         - solver.Value(var_c[j])
#                         + solver.Value(var_s[j]),
#                     ]
#                 )
#                 + para_delta[m]
#             )
#             bool_right = (
#                 solver.Value(var_s[i])
#                 >= solver.Value(var_s[j])
#                 + max(
#                     [
#                         0,
#                         solver.Value(var_c[j])
#                         - solver.Value(var_s[j])
#                         - solver.Value(var_c[i])
#                         + solver.Value(var_s[i]),
#                     ]
#                 )
#                 + para_delta[m]
#             )
#             assert bool_left or bool_right

# %%
var_c_max
# Out:
# 707.0

# %%
model.ExportToFile("CP_model_50.pb.txt")
# Out:
# True

# %%
# del check_constraints_milp
# del check_constraints_cp

# %%
from checking_constraints import check_constraints_milp, check_constraints_cp

# import importlib
# importlib.reload(check_constraints_milp)

# %load_ext autoreload
# %autoreload 2

# %%
def get_values(var):
    return solver.Value(var)


v_get_values = np.vectorize(get_values)

var_y = v_get_values(fjss2.var_y)
var_s = v_get_values(fjss2.var_s)
var_c = v_get_values(fjss2.var_c)
var_c_max = fjss2.var_c_max
var_u = v_get_values(fjss2.var_u)
num_t = int(fjss2.horizon / 1.0e0)

print(var_c_max)

# check if solutions from CP satisfy the constraints of CP formulation
check_constraints_cp(
    var_y=var_y,
    var_s=var_s,
    var_c=var_c,
    var_c_max=var_c_max,
    var_u=var_u,
    operations=operations,
    machines=machines,
    para_p=para_p,
    para_a=para_a,
    para_w=para_w,
    para_h=para_h,
    para_delta=para_delta,
    para_mach_capacity=para_mach_capacity,
    para_lmin=para_lmin,
    para_lmax=para_lmax,
    num_t=num_t,
)
# Out:
# 707.0

# %%
# check if the solution from CP still satisfies the constraints of MILP
check_constraints_milp(
    var_y=var_y,
    var_s=var_s,
    var_c=var_c,
    var_c_max=var_c_max,
    operations=operations,
    machines=machines,
    para_p=para_p,
    para_a=np.einsum("mij->ijm", para_a),
    para_w=para_w,
    para_h=para_h,
    para_delta=para_delta,
    para_mach_capacity=para_mach_capacity,
    para_lmin=para_lmin,
    para_lmax=para_lmax,
    big_m=big_m,
    var_x=None,
    var_z=None,
)

# %%
# %autoreload 0 - disables the auto-reloading. This is the default setting.
# %autoreload 1 - it will only auto-reload modules that were imported using the %aimport function (e.g %aimport my_module). It's a good option if you want to specifically auto-reload only a selected module.

# %autoreload 2 - auto-reload all the modules. Great way to make writing and testing your modules much easier.

# %%
from fjss import FjsOutput, SolvedOperation

assignments = dict()
start_times = dict()
end_times = dict()
solved_operations = []

# Task="Job A", Start='2009-01-01', Finish='2009-02-28', Completion_pct=50
df = pd.DataFrame(columns=["operation", "machine", "start_time", "end_time"])

for i, m in product(range(len(fjss2.operations)), range(len(fjss2.machines))):
    if solver.Value(fjss2.var_y[i, m]) == 1:
        assignments[fjss2.operations[i]] = fjss2.machines[m]
        start_times[fjss2.operations[i]] = solver.Value(fjss2.var_s[i])
        end_times[fjss2.operations[i]] = solver.Value(fjss2.var_c[i])
        solved_operation = SolvedOperation(
            id=fjss2.operations[i],
            assigned_to=fjss2.machines[m],
            start_time=solver.Value(fjss2.var_s[i]),
            end_time=solver.Value(fjss2.var_c[i]),
        )
        solved_operations.append(solved_operation)

        df.loc[i, "operation"] = fjss2.operations[i]
        df.loc[i, "machine"] = fjss2.machines[m]
        df.loc[i, "start_time"] = solver.Value(fjss2.var_s[i])
        df.loc[i, "end_time"] = solver.Value(fjss2.var_c[i])

fjs_output = FjsOutput(
    solved_operations=solved_operations,
    makespan=solver.ObjectiveValue(),
)

# %%
fjs_output
# Out:
# FjsOutput(solved_operations=[SolvedOperation(id='0', assigned_to='0', start_time=50.0, end_time=55.0), SolvedOperation(id='1', assigned_to='4', start_time=72.0, end_time=366.0), SolvedOperation(id='2', assigned_to='1', start_time=371.0, end_time=376.0), SolvedOperation(id='3', assigned_to='4', start_time=386.0, end_time=474.0), SolvedOperation(id='4', assigned_to='2', start_time=479.0, end_time=489.0), SolvedOperation(id='5', assigned_to='4', start_time=496.0, end_time=564.0), SolvedOperation(id='6', assigned_to='2', start_time=565.0, end_time=575.0), SolvedOperation(id='7', assigned_to='4', start_time=578.0, end_time=646.0), SolvedOperation(id='8', assigned_to='2', start_time=646.0, end_time=656.0), SolvedOperation(id='9', assigned_to='0', start_time=0.0, end_time=5.0), SolvedOperation(id='10', assigned_to='5', start_time=5.0, end_time=329.0), SolvedOperation(id='11', assigned_to='1', start_time=333.0, end_time=338.0), SolvedOperation(id='12', assigned_to='5', start_time=338.0, end_time=419.0), SolvedOperation(id='13', assigned_to='2', start_time=424.0, end_time=434.0), SolvedOperation(id='14', assigned_to='5', start_time=434.0, end_time=515.0), SolvedOperation(id='15', assigned_to='2', start_time=515.0, end_time=525.0), SolvedOperation(id='16', assigned_to='5', start_time=525.0, end_time=606.0), SolvedOperation(id='17', assigned_to='2', start_time=606.0, end_time=616.0), SolvedOperation(id='18', assigned_to='5', start_time=616.0, end_time=697.0), SolvedOperation(id='19', assigned_to='2', start_time=697.0, end_time=707.0), SolvedOperation(id='20', assigned_to='0', start_time=40.0, end_time=45.0), SolvedOperation(id='21', assigned_to='4', start_time=100.0, end_time=394.0), SolvedOperation(id='22', assigned_to='1', start_time=399.0, end_time=404.0), SolvedOperation(id='23', assigned_to='4', start_time=414.0, end_time=485.0), SolvedOperation(id='24', assigned_to='2', start_time=490.0, end_time=500.0), SolvedOperation(id='25', assigned_to='4', start_time=500.0, end_time=572.0), SolvedOperation(id='26', assigned_to='2', start_time=577.0, end_time=587.0), SolvedOperation(id='27', assigned_to='4', start_time=587.0, end_time=655.0), SolvedOperation(id='28', assigned_to='2', start_time=659.0, end_time=669.0), SolvedOperation(id='29', assigned_to='0', start_time=30.0, end_time=35.0), SolvedOperation(id='30', assigned_to='3', start_time=35.0, end_time=316.0), SolvedOperation(id='31', assigned_to='1', start_time=321.0, end_time=326.0), SolvedOperation(id='32', assigned_to='3', start_time=328.0, end_time=398.0), SolvedOperation(id='33', assigned_to='2', start_time=399.0, end_time=409.0), SolvedOperation(id='34', assigned_to='0', start_time=10.0, end_time=15.0), SolvedOperation(id='35', assigned_to='3', start_time=27.0, end_time=236.0), SolvedOperation(id='36', assigned_to='1', start_time=238.0, end_time=243.0), SolvedOperation(id='37', assigned_to='3', start_time=253.0, end_time=317.0), SolvedOperation(id='38', assigned_to='2', start_time=317.0, end_time=327.0), SolvedOperation(id='39', assigned_to='3', start_time=327.0, end_time=374.0), SolvedOperation(id='40', assigned_to='2', start_time=374.0, end_time=384.0), SolvedOperation(id='41', assigned_to='3', start_time=393.0, end_time=454.0), SolvedOperation(id='42', assigned_to='2', start_time=454.0, end_time=464.0), SolvedOperation(id='43', assigned_to='3', start_time=470.0, end_time=535.0), SolvedOperation(id='44', assigned_to='2', start_time=540.0, end_time=550.0), SolvedOperation(id='45', assigned_to='0', start_time=20.0, end_time=25.0), SolvedOperation(id='46', assigned_to='3', start_time=34.0, end_time=243.0), SolvedOperation(id='47', assigned_to='1', start_time=248.0, end_time=253.0), SolvedOperation(id='48', assigned_to='3', start_time=256.0, end_time=323.0), SolvedOperation(id='49', assigned_to='2', start_time=328.0, end_time=338.0)], makespan=707.0)

# %%
df
# Out:
#    operation machine start_time end_time
# 0          0       0         50       55
# 1          1       4         72      366
# 2          2       1        371      376
# 3          3       4        386      474
# 4          4       2        479      489
# 5          5       4        496      564
# 6          6       2        565      575
# 7          7       4        578      646
# 8          8       2        646      656
# 9          9       0          0        5
# 10        10       5          5      329
# 11        11       1        333      338
# 12        12       5        338      419
# 13        13       2        424      434
# 14        14       5        434      515
# 15        15       2        515      525
# 16        16       5        525      606
# 17        17       2        606      616
# 18        18       5        616      697
# 19        19       2        697      707
# 20        20       0         40       45
# 21        21       4        100      394
# 22        22       1        399      404
# 23        23       4        414      485
# 24        24       2        490      500
# 25        25       4        500      572
# 26        26       2        577      587
# 27        27       4        587      655
# 28        28       2        659      669
# 29        29       0         30       35
# 30        30       3         35      316
# 31        31       1        321      326
# 32        32       3        328      398
# 33        33       2        399      409
# 34        34       0         10       15
# 35        35       3         27      236
# 36        36       1        238      243
# 37        37       3        253      317
# 38        38       2        317      327
# 39        39       3        327      374
# 40        40       2        374      384
# 41        41       3        393      454
# 42        42       2        454      464
# 43        43       3        470      535
# 44        44       2        540      550
# 45        45       0         20       25
# 46        46       3         34      243
# 47        47       1        248      253
# 48        48       3        256      323
# 49        49       2        328      338

# %%
df.to_csv("CP_for_gantt_chart.csv")
