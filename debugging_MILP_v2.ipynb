# %%
from fjss import FJSS2, FJSS3, FJSS4
import numpy as np
import time

from itertools import product
from collections import OrderedDict

from ortools.linear_solver import pywraplp
from ortools.sat.python import cp_model

from utils import parse_data
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
infinity = 1.0e6
n_opt_selected = 20

# %%
def load_data():
    n_opt, n_mach, operation_data, machine_data = parse_data(
        input_fname="gfjsp_10_5_1.txt"
    )
    operation_data["0"]["h"] = 0
    operation_data["1"]["h"] = 0
    operation_data["2"]["h"] = 0
    operation_data["3"]["h"] = 20

    # define the parameters

    # minimum lag between the starting time of operation i and the ending time of operation j
    para_lmin = np.full((n_opt, n_opt), dtype=object, fill_value=-np.inf)
    # maximum lag between the starting time of operation i and the ending time of operation j
    para_lmax = np.full((n_opt, n_opt), dtype=object, fill_value=np.inf)

    # processing time of operation i in machine m
    # para_p = np.full((n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_p = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)

    # the shape of h in the original file is (n_machine) while the shape of para_h in the
    # paper is (n_opt, n_mach)
    # maximum holding time of operation i in machine m
    para_h = np.empty((n_opt, n_mach), dtype=object)

    # mapping of operation i to machine m
    # 20 for the furnaces, 0 for Cutting, Pressing, and Forging
    # 0: Cutting; 1: Pressing; 2: Forging; 3: Furnace
    holding_time_dict = {
        "0": 0,
        "1": 0,
        "2": 0,
        "3": 20,
    }

    # weight of operation i in machine m
    # para_w = np.empty((n_opt, n_mach), dtype=object)
    # para_w = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)
    para_w = np.full((n_mach, n_opt), dtype=object, fill_value=0)

    # input/output delay time between two consecutive operations in mahcine m
    # para_delta = np.empty((n_mach), dtype=object)
    para_delta = np.full((n_mach), dtype=object, fill_value=0)

    # setup time of machine m when processing operation i before j
    # para_a = np.full((n_opt, n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_a = np.full((n_mach, n_opt, n_opt), dtype=object, fill_value=-np.inf)

    # capacity of machine
    # para_mach_capacity = np.empty((n_mach), dtype=object)
    para_mach_capacity = np.full((n_mach), dtype=object, fill_value=0)
    for m in range(n_mach):
        # capacity of machine is a set of constant numbers
        para_mach_capacity[m] = machine_data[str(m)]["c"]

        # input/output delay time between two consecutive operations in mahcine m
        # delta(m): loading and unloading time of machine m (=1 for all machines)
        para_delta[m] = 1

        # set up time of machine m when processing operation i before j
        # a(i,j,m): setup time of machine m when processing operation i before j (aijm = -inf if there
        # is no setups)
        for idx_setup, setup_data in enumerate(machine_data[str(m)]["setup_data"][0]):
            para_a[m, int(setup_data[0]), int(setup_data[1])] = setup_data[2]

        # maximum holding time of operation i in machine m
        para_h[:, m] = holding_time_dict[str(machine_data[str(m)]["t"])]

    # lag time
    for i in range(n_opt):
        for idx_lag, lag_data in enumerate(operation_data[str(i)]["lag"]):
            # minimum lag between the starting time of operation i and the ending time of operation j
            para_lmin[i, int(lag_data[0])] = lag_data[1]
            # maximum lag between the starting time of operation i and the ending time of operation j
            para_lmax[i, int(lag_data[0])] = lag_data[2]

        for idx_pw, pw_data in enumerate(operation_data[str(i)]["pw"]):
            # operation_data[str(1)]["pw"]
            # # the shape of para_p in the original file is the transpose of the shape of para_p
            # para_p[i, int(pw_data[0])] = pw_data[1]
            # # the shape of para_w in the original file is the transpose of the shape of para_w
            # para_w[i, int(pw_data[0])] = pw_data[2]

            # the shape of para_p in the original file is the transpose of the shape of para_p
            para_p[int(pw_data[0]), i] = pw_data[1]
            # the shape of para_w in the original file is the transpose of the shape of para_w
            para_w[int(pw_data[0]), i] = pw_data[2]

    # reformat the shape of para_p and para_w
    para_p = para_p.T
    para_w = para_w.T

    # # reshape the shape of para_a
    # para_a = np.einsum("mij->ijm", para_a)

    return (
        n_opt,
        n_mach,
        operation_data,
        machine_data,
        para_lmin,
        para_lmax,
        para_p,
        para_h,
        para_w,
        para_delta,
        para_a,
        para_mach_capacity,
    )

# %%
(
    n_opt,
    n_mach,
    operation_data,
    machine_data,
    para_lmin,
    para_lmax,
    para_p,
    para_h,
    para_w,
    para_delta,
    para_a,
    para_mach_capacity,
) = load_data()
n_opt = n_opt_selected
para_p_horizon = np.copy(para_p[:n_opt_selected, :])
para_p_horizon[para_p_horizon == np.inf] = 0
# para_h = np.empty((n_opt, n_mach), dtype=object)
para_h_horizon = np.copy(para_h[:n_opt_selected, :])
para_h_horizon[para_h_horizon == np.inf] = 0
para_lmax_horizon = np.copy(para_lmax[:n_opt_selected, :n_opt_selected])
para_lmax_horizon[para_lmax_horizon == np.inf] = 0
horizon = (
    np.sum(para_p_horizon, axis=1)
    + np.sum(para_h_horizon, axis=1)
    + np.sum(para_lmax_horizon, axis=1)
)
horizon = int(np.sum(horizon)) + 1
# para_lmin[para_lmin == -np.inf] = -infinity
# para_lmin[para_lmin == np.inf] = infinity
# para_lmax[para_lmax == np.inf] = infinity
# para_lmax[para_lmax == -np.inf] = -infinity
# para_p[para_p == np.inf] = infinity
# para_p[para_p == -np.inf] = -infinity
# para_w[para_w == np.inf] = infinity
# para_w[para_w == -np.inf] = -infinity
# para_a[para_a == np.inf] = infinity
# para_a[para_a == -np.inf] = -infinity
# =====================================================
# convert all the numpy arrays with integers data type
# para_lmin = para_lmin.astype(int)
# para_lmax = para_lmax.astype(int)
# para_p = para_p.astype(int)
# para_w = para_w.astype(int)
# para_a = para_a.astype(int)
# para_delta = para_delta.astype(int)
# para_mach_capacity = para_mach_capacity.astype(int)

para_lmin = para_lmin[:n_opt_selected, :n_opt_selected]
para_lmax = para_lmax[:n_opt_selected, :n_opt_selected]
para_p = para_p[:n_opt_selected, :]
para_h = para_h[:n_opt_selected, :]
para_w = para_w[:n_opt_selected, :]
para_a = para_a[:n_opt_selected, :n_opt_selected, :]
# machines
machines = [str(i) for i in range(n_mach)]
# operations
operations = [str(i) for i in range(n_opt_selected)]
operations = operations[:n_opt_selected]
machines = machines[:n_mach]

# %%
# def get_m_value_old(para_p, para_h, para_lmin, para_a):
#     selected_idx = np.argwhere(para_p != np.inf)
#     # eq. (17)
#     p_i = para_p[selected_idx] + para_h[selected_idx]
#     p_i = np.max(p_i[p_i != np.inf])
#     # eq. (18)
#     l_i = np.max(para_lmin, axis=1)
#     # setup time of machine m when processing operation i before j (aijm = -inf if there is no
#     # setups).
#     # eq. (19)
#     # TODO: check if this is correct
#     # para_a = np.einsum("mij->ijm", para_a)
#     n_opt, n_mach = para_h.shape
#     if para_a.shape != (n_opt, n_opt, n_mach):
#         para_a = np.einsum("mij->ijm", para_a)

#     selected_a = para_a[selected_idx, :]
#     a_i = selected_a[selected_a != np.inf]

#     # eq. (20) adapted
#     big_m = np.sum(p_i) + np.max([l_i.max(), a_i.max()])

#     return big_m


# def get_m_value_runzhong(para_p, para_h, para_lmin, para_a):
#     """Implementation after discussion with Runzhong."""
#     selected_idx = np.argwhere(para_p != np.inf)
#     # eq. (17)
#     para_p[para_p == np.inf] = 0
#     p_i = np.max(para_p + para_h, axis=1)

#     # eq. (18)
#     # print(f"para_min={para_lmin}")
#     para_lmin[para_lmin < 0] = 0
#     l_i = np.max(para_lmin, axis=1)

#     n_opt, n_mach = para_h.shape
#     if para_a.shape != (n_opt, n_opt, n_mach):
#         para_a = np.einsum("mij->ijm", para_a)
#     # eq. (19)
#     # para_a[selected_idx[:, 0], :, selected_idx[:, 1]] = 0
#     para_a[para_a == -np.inf] = 0
#     a_i = np.max(para_a, axis=(1, 2))
#     print(a_i)

#     # eq. (20)
#     l_a_max = [max(l_element, a_element) for l_element, a_element in zip(l_i, a_i)]
#     big_m = np.max(p_i + np.array(l_a_max))

#     return big_m

# %% [markdown]
# ## Debugging the Original MILP, FJSS3

# %%
# start_time = time.time()

if para_a.shape != (n_opt, n_opt, n_mach):
    para_a = np.einsum("mij->ijm", para_a)

fjss3 = FJSS3(
    operations=operations,
    machines=machines,
    para_p=para_p,
    para_a=para_a,
    para_w=para_w,
    para_h=para_h,
    para_delta=para_delta,
    para_mach_capacity=para_mach_capacity,
    para_lmin=para_lmin,
    para_lmax=para_lmax,
    precedence=None,
    model_string=None,
    inf_milp=infinity,
    num_workers=4,
    verbose=True,
    big_m=None,
)
fjss3.build_model_gurobi()
fjss3.solve_gurobi()
# running_time = time.time() - start_time

# using get_m_value_old works

# using get_m_value_runzhong does not work, big_m=374
# Out:
# type of big_m: <class 'float'>
# big_m=1916.0
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-15
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07
# Set parameter OptimalityTol to value 1e-07
# Set parameter Presolve to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 10080 rows, 2961 columns and 50580 nonzeros
# Model fingerprint: 0xcfa532ea
# Variable types: 41 continuous, 2920 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 1684 rows and 2378 columns
# Presolve time: 0.05s
# Presolved: 8396 rows, 583 columns, 39979 nonzeros
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706239219.065752 4028473 environment.cc:405] Found the Gurobi library in '/Library/gurobi1003/macos_universal2/lib/libgurobi100.dylib.
# Variable types: 41 continuous, 542 integer (542 binary)
#
# Root relaxation: objective 0.000000e+00, 192 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   28          -    0.00000      -     -    0s
#      0     0    0.00000    0   28          -    0.00000      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (866 simplex iterations) in 0.57 seconds (1.14 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# No solution found.

# %%
print(f"big_m = {fjss3.big_m}")
# Out:
# big_m = 1916.0

# %%
# get_m_value(para_p=para_p, para_h=para_h, para_lmin=para_lmin, para_a=para_a)

# %%
# # eq. (20) adapted
# big_m = np.sum(p_i) + np.max([l_i.max(), a_i.max()])

# big_m

# %%
# TODO: fix this

# start_time = time.time()
fjss4 = FJSS4(
    operations=operations,
    machines=machines,
    para_p=para_p,
    para_a=para_a,
    para_w=para_w,
    para_h=para_h,
    para_delta=para_delta,
    para_mach_capacity=para_mach_capacity,
    para_lmin=para_lmin,
    para_lmax=para_lmax,
    precedence=None,
    model_string=None,
    inf_milp=infinity,
    num_workers=4,
    verbose=True,
    big_m=10000,
)
fjss4.build_model_gurobi()
fjss4.solve_gurobi()
# running_time = time.time() - start_time
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-15
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 10080 rows, 2961 columns and 50580 nonzeros
# Model fingerprint: 0x1a324029
# Variable types: 41 continuous, 2920 integer (2920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-05, 4e+08]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 812 rows and 1934 columns
# Presolve time: 0.04s
# Presolved: 9268 rows, 1027 columns, 44925 nonzeros
# Variable types: 41 continuous, 986 integer (986 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.000000e-05, 906 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00001    0   30          -    0.00001      -     -    0s
#      0     0    0.00001    0   28          -    0.00001      -     -    0s
#      0     2    0.00001    0   28          -    0.00001      -     -    0s
#
# Explored 17159 nodes (144258 simplex iterations) in 4.06 seconds (10.12 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# No solution found.

# %%
# fjss4.model.computeIIS()

# %%
from checking_constraints import check_constraints_milp, check_constraints_cp

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_values(var):
    return var.solution_value()


v_get_values = np.vectorize(get_values)

var_y = v_get_values(fjss3.var_y)
var_s = v_get_values(fjss3.var_s)
var_c = v_get_values(fjss3.var_c)
var_c_max = fjss3.var_c_max
var_x = v_get_values(fjss3.var_x)
var_z = v_get_values(fjss3.var_z)

# check_constraints_cp(
#     var_y=var_y,
#     var_s=var_s,
#     var_c=var_c,
#     var_c_max=var_c_max,
#     var_u=None,
#     operations=operations,
#     machines=machines,
#     para_p=para_p,
#     para_a=para_a,
#     para_w=para_w,
#     para_h=para_h,
#     para_delta=para_delta,
#     para_mach_capacity=para_mach_capacity,
#     para_lmin=para_lmin,
#     para_lmax=para_lmax,
#     num_t=None,
# )
# Out:
# E0000 00:00:1706239224.173472 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174165 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174169 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174170 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174171 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174173 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174175 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174176 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174178 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174179 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174181 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174182 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174182 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174184 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174184 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174186 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174188 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174189 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174190 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174191 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174192 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174193 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174194 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174195 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174199 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174200 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174201 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174202 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174203 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174204 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174204 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174207 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174207 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174208 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174209 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174210 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174211 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174212 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174213 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174214 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174215 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174216 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174217 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174218 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174219 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174220 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174221 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174222 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174223 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174224 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174225 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174226 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174226 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174228 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174229 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174229 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174230 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174231 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174232 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174233 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174234 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174240 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174241 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174242 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174243 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174244 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174245 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174246 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174247 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174248 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174248 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174249 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174251 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174251 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174252 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174253 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174254 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174255 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174256 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174257 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174258 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174259 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174260 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174261 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174262 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174263 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174264 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174264 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174265 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174266 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174267 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174268 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174269 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174270 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174271 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174272 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174273 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174274 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174275 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174276 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174277 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174278 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174279 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174280 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174280 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174281 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174282 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174283 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174284 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174285 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174286 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174287 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174288 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174289 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174290 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174291 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174292 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174293 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174294 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174294 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174295 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174392 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174400 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174401 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174402 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174404 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174405 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174406 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174406 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174407 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174408 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174409 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174410 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174411 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174412 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174413 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174414 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174415 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174416 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174417 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174418 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174419 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174440 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174446 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174447 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174448 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174449 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174450 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174451 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174452 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174453 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174454 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174455 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174456 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174457 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174458 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174458 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174460 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174460 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174461 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174462 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174464 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174464 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174490 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174502 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174503 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174505 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174506 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174507 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174508 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174509 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174510 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174511 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174512 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174513 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174514 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174515 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174516 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174517 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174518 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174519 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174520 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174521 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174522 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174523 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174524 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174525 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174526 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174527 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174528 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174529 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174530 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174531 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174532 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174533 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174533 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174534 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174535 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174537 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174538 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174539 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174540 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174541 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174542 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174543 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174544 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174544 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174545 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174546 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174547 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174548 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174549 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174550 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174551 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174552 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174553 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174554 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174555 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174556 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174557 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174558 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174559 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174560 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174561 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174561 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174562 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174563 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174564 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174565 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174566 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174567 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174568 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174569 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174570 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174571 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174572 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174573 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174574 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174574 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174575 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174576 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174577 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174578 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174579 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174580 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174581 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174582 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174583 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174584 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174584 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174585 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174586 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174587 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174588 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174589 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174590 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174591 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174592 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174593 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174593 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174594 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174595 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174596 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174597 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174598 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174599 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174600 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174601 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174602 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174603 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174604 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174605 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174606 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174606 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174607 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174608 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174609 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174610 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174611 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174612 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174613 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174614 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174615 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174616 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174617 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174618 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174618 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174619 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174620 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174621 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174622 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174623 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174624 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174625 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174626 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174627 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174628 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174628 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174629 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174630 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174631 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174632 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174633 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174634 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174635 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174636 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174637 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174638 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174639 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174640 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174641 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174642 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174643 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174644 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174645 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174646 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174647 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174648 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174649 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174650 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174651 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174652 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174653 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174654 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174654 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174655 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174656 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174657 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174658 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174659 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174660 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174661 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174662 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174663 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174664 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174665 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174666 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174667 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174668 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174668 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174670 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174670 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174671 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174672 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174673 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174674 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174675 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174676 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174677 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174678 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# ...
# E0000 00:00:1706239224.174704 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174705 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174706 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174707 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174708 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174709 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174710 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174711 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174712 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174713 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174714 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174714 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174715 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174716 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174717 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174718 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174719 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174720 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174721 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174722 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174723 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174724 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174725 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174726 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174726 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174727 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174728 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174729 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174730 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174731 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174732 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174733 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174734 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174735 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174736 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174737 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174737 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174738 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174739 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174740 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174741 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174742 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174743 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174744 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174745 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174746 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174747 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174748 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174749 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174750 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174751 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174752 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174753 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174754 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174755 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174756 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174757 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174758 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174759 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174760 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174761 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174762 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174763 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174764 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174765 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174766 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174767 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174768 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174769 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174770 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174771 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174772 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174773 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174774 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174775 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174776 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174777 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174778 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174779 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174780 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174781 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174782 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174784 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174785 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174786 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174787 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174787 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174789 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174790 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174791 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174792 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174793 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174794 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174795 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174796 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174797 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174798 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174799 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174800 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174801 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174802 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706239224.174803 4028473 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 11
#       9 var_c = v_get_values(fjss3.var_c)
#      10 var_c_max = fjss3.var_c_max
# ---> 11 var_x = v_get_values(fjss3.var_x)
#      12 var_z = v_get_values(fjss3.var_z)
#      14 # check_constraints_cp(
#      15 #     var_y=var_y,
#      16 #     var_s=var_s,
#    (...)
#      30 #     num_t=None,
#      31 # )
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:2372, in vectorize.__call__(self, *args, **kwargs)
#    2369     self._init_stage_2(*args, **kwargs)
#    2370     return self
# -> 2372 return self._call_as_normal(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:2365, in vectorize._call_as_normal(self, *args, **kwargs)
#    2362     vargs = [args[_i] for _i in inds]
#    2363     vargs.extend([kwargs[_n] for _n in names])
# -> 2365 return self._vectorize_call(func=func, args=vargs)
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:2455, in vectorize._vectorize_call(self, func, args)
#    2452 # Convert args to object arrays first
#    2453 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2455 outputs = ufunc(*inputs)
#    2457 if ufunc.nout == 1:
#    2458     res = asanyarray(outputs, dtype=otypes[0])
#
# Cell In[14], line 2, in get_values(var)
#       1 def get_values(var):
# ----> 2     return var.solution_value()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/solver_py311/lib/python3.11/site-packages/ortools/linear_solver/pywraplp.py:662, in Variable.solution_value(self)
#     654 def solution_value(self):
#     655     r"""
#     656     Returns the value of the variable in the current solution.
#     657
#    (...)
#     660     automatically rounds it to the nearest integer; see: man 3 round).
#     661     """
# --> 662     return _pywraplp.Variable_solution_value(self)
#
# KeyboardInterrupt:

# %%
para_a[:, :, :] = -infinity

big_m = fjss3.big_m

check_constraints_milp(
    var_y=var_y,
    var_s=var_s,
    var_c=var_c,
    var_c_max=var_c_max,
    operations=operations,
    machines=machines,
    para_p=fjss3.para_p,
    para_a=fjss3.para_a,
    para_w=fjss3.para_w,
    para_h=fjss3.para_h,
    para_delta=fjss3.para_delta,
    para_mach_capacity=fjss3.para_mach_capacity,
    para_lmin=fjss3.para_lmin,
    para_lmax=fjss3.para_lmax,
    big_m=fjss3.big_m,
    var_x=var_x,
    var_z=var_z,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 21
#       1 para_a[:, :, :] = -infinity
#       3 big_m = fjss3.big_m
#       5 check_constraints_milp(
#       6     var_y=var_y,
#       7     var_s=var_s,
#       8     var_c=var_c,
#       9     var_c_max=var_c_max,
#      10     operations=operations,
#      11     machines=machines,
#      12     para_p=fjss3.para_p,
#      13     para_a=fjss3.para_a,
#      14     para_w=fjss3.para_w,
#      15     para_h=fjss3.para_h,
#      16     para_delta=fjss3.para_delta,
#      17     para_mach_capacity=fjss3.para_mach_capacity,
#      18     para_lmin=fjss3.para_lmin,
#      19     para_lmax=fjss3.para_lmax,
#      20     big_m=fjss3.big_m,
# ---> 21     var_x=var_x,
#      22     var_z=var_z,
#      23 )
#
# NameError: name 'var_x' is not defined

# %%
big_m
# Out:
# 1000050.0

# %%
n_opt, n_mach, operation_data, machine_data = parse_data("gfjsp_10_5_1.txt")

# %%
para_delta
# Out:
# array([1, 1, 1, 1, 1, 1], dtype=object)

# %%
    for m in range(n_mach):
        for idx_setup, setup_data in enumerate(machine_data[str(m)]["setup_data"][0]):
            print(setup_data[2])
# Out:
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
