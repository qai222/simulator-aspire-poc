# %%
from fjss import FJSS2, FJSS3, FJSS4
import numpy as np
import time

from itertools import product
from collections import OrderedDict

from ortools.linear_solver import pywraplp
from ortools.sat.python import cp_model

from utils import parse_data
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
infinity = 1.0e6
n_opt_selected = 20

# %%
def load_data():
    n_opt, n_mach, operation_data, machine_data = parse_data(
        input_fname="gfjsp_10_5_1.txt"
    )
    operation_data["0"]["h"] = 0
    operation_data["1"]["h"] = 0
    operation_data["2"]["h"] = 0
    operation_data["3"]["h"] = 20

    # define the parameters

    # minimum lag between the starting time of operation i and the ending time of operation j
    para_lmin = np.full((n_opt, n_opt), dtype=object, fill_value=-np.inf)
    # maximum lag between the starting time of operation i and the ending time of operation j
    para_lmax = np.full((n_opt, n_opt), dtype=object, fill_value=np.inf)

    # processing time of operation i in machine m
    # para_p = np.full((n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_p = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)

    # the shape of h in the original file is (n_machine) while the shape of para_h in the
    # paper is (n_opt, n_mach)
    # maximum holding time of operation i in machine m
    para_h = np.empty((n_opt, n_mach), dtype=object)

    # mapping of operation i to machine m
    # 20 for the furnaces, 0 for Cutting, Pressing, and Forging
    # 0: Cutting; 1: Pressing; 2: Forging; 3: Furnace
    holding_time_dict = {
        "0": 0,
        "1": 0,
        "2": 0,
        "3": 20,
    }

    # weight of operation i in machine m
    # para_w = np.empty((n_opt, n_mach), dtype=object)
    # para_w = np.full((n_mach, n_opt), dtype=object, fill_value=np.inf)
    para_w = np.full((n_mach, n_opt), dtype=object, fill_value=0)

    # input/output delay time between two consecutive operations in mahcine m
    # para_delta = np.empty((n_mach), dtype=object)
    para_delta = np.full((n_mach), dtype=object, fill_value=0)

    # setup time of machine m when processing operation i before j
    # para_a = np.full((n_opt, n_opt, n_mach), dtype=object, fill_value=np.inf)
    para_a = np.full((n_mach, n_opt, n_opt), dtype=object, fill_value=-np.inf)

    # capacity of machine
    # para_mach_capacity = np.empty((n_mach), dtype=object)
    para_mach_capacity = np.full((n_mach), dtype=object, fill_value=0)
    for m in range(n_mach):
        # capacity of machine is a set of constant numbers
        para_mach_capacity[m] = machine_data[str(m)]["c"]

        # input/output delay time between two consecutive operations in mahcine m
        # delta(m): loading and unloading time of machine m (=1 for all machines)
        para_delta[m] = 1

        # set up time of machine m when processing operation i before j
        # a(i,j,m): setup time of machine m when processing operation i before j (aijm = -inf if there
        # is no setups)
        for idx_setup, setup_data in enumerate(machine_data[str(m)]["setup_data"][0]):
            para_a[m, int(setup_data[0]), int(setup_data[1])] = setup_data[2]

        # maximum holding time of operation i in machine m
        para_h[:, m] = holding_time_dict[str(machine_data[str(m)]["t"])]

    # lag time
    for i in range(n_opt):
        for idx_lag, lag_data in enumerate(operation_data[str(i)]["lag"]):
            # minimum lag between the starting time of operation i and the ending time of operation j
            para_lmin[i, int(lag_data[0])] = lag_data[1]
            # maximum lag between the starting time of operation i and the ending time of operation j
            para_lmax[i, int(lag_data[0])] = lag_data[2]

        for idx_pw, pw_data in enumerate(operation_data[str(i)]["pw"]):
            # operation_data[str(1)]["pw"]
            # # the shape of para_p in the original file is the transpose of the shape of para_p
            # para_p[i, int(pw_data[0])] = pw_data[1]
            # # the shape of para_w in the original file is the transpose of the shape of para_w
            # para_w[i, int(pw_data[0])] = pw_data[2]

            # the shape of para_p in the original file is the transpose of the shape of para_p
            para_p[int(pw_data[0]), i] = pw_data[1]
            # the shape of para_w in the original file is the transpose of the shape of para_w
            para_w[int(pw_data[0]), i] = pw_data[2]

    # reformat the shape of para_p and para_w
    para_p = para_p.T
    para_w = para_w.T

    # # reshape the shape of para_a
    # para_a = np.einsum("mij->ijm", para_a)

    return (
        n_opt,
        n_mach,
        operation_data,
        machine_data,
        para_lmin,
        para_lmax,
        para_p,
        para_h,
        para_w,
        para_delta,
        para_a,
        para_mach_capacity,
    )

# %%
(
    n_opt,
    n_mach,
    operation_data,
    machine_data,
    para_lmin,
    para_lmax,
    para_p,
    para_h,
    para_w,
    para_delta,
    para_a,
    para_mach_capacity,
) = load_data()
n_opt = n_opt_selected
para_p_horizon = np.copy(para_p[:n_opt_selected, :])
para_p_horizon[para_p_horizon == np.inf] = 0
# para_h = np.empty((n_opt, n_mach), dtype=object)
para_h_horizon = np.copy(para_h[:n_opt_selected, :])
para_h_horizon[para_h_horizon == np.inf] = 0
para_lmax_horizon = np.copy(para_lmax[:n_opt_selected, :n_opt_selected])
para_lmax_horizon[para_lmax_horizon == np.inf] = 0
horizon = (
    np.sum(para_p_horizon, axis=1)
    + np.sum(para_h_horizon, axis=1)
    + np.sum(para_lmax_horizon, axis=1)
)
horizon = int(np.sum(horizon)) + 1
# para_lmin[para_lmin == -np.inf] = -infinity
# para_lmin[para_lmin == np.inf] = infinity
# para_lmax[para_lmax == np.inf] = infinity
# para_lmax[para_lmax == -np.inf] = -infinity
# para_p[para_p == np.inf] = infinity
# para_p[para_p == -np.inf] = -infinity
# para_w[para_w == np.inf] = infinity
# para_w[para_w == -np.inf] = -infinity
# para_a[para_a == np.inf] = infinity
# para_a[para_a == -np.inf] = -infinity
# =====================================================
# convert all the numpy arrays with integers data type
# para_lmin = para_lmin.astype(int)
# para_lmax = para_lmax.astype(int)
# para_p = para_p.astype(int)
# para_w = para_w.astype(int)
# para_a = para_a.astype(int)
# para_delta = para_delta.astype(int)
# para_mach_capacity = para_mach_capacity.astype(int)

para_lmin = para_lmin[:n_opt_selected, :n_opt_selected]
para_lmax = para_lmax[:n_opt_selected, :n_opt_selected]
para_p = para_p[:n_opt_selected, :]
para_h = para_h[:n_opt_selected, :]
para_w = para_w[:n_opt_selected, :]
para_a = para_a[:n_opt_selected, :n_opt_selected, :]
# machines
machines = [str(i) for i in range(6)]
# operations
operations = [str(i) for i in range(n_opt_selected)]
operations = operations[:n_opt_selected]
machines = machines[:n_mach]

# %%
# def get_m_value_old(para_p, para_h, para_lmin, para_a):
#     selected_idx = np.argwhere(para_p != np.inf)
#     # eq. (17)
#     p_i = para_p[selected_idx] + para_h[selected_idx]
#     p_i = np.max(p_i[p_i != np.inf])
#     # eq. (18)
#     l_i = np.max(para_lmin, axis=1)
#     # setup time of machine m when processing operation i before j (aijm = -inf if there is no
#     # setups).
#     # eq. (19)
#     # TODO: check if this is correct
#     # para_a = np.einsum("mij->ijm", para_a)
#     n_opt, n_mach = para_h.shape
#     if para_a.shape != (n_opt, n_opt, n_mach):
#         para_a = np.einsum("mij->ijm", para_a)

#     selected_a = para_a[selected_idx, :]
#     a_i = selected_a[selected_a != np.inf]

#     # eq. (20) adapted
#     big_m = np.sum(p_i) + np.max([l_i.max(), a_i.max()])

#     return big_m


# def get_m_value_runzhong(para_p, para_h, para_lmin, para_a):
#     """Implementation after discussion with Runzhong."""
#     selected_idx = np.argwhere(para_p != np.inf)
#     # eq. (17)
#     para_p[para_p == np.inf] = 0
#     p_i = np.max(para_p + para_h, axis=1)

#     # eq. (18)
#     # print(f"para_min={para_lmin}")
#     para_lmin[para_lmin < 0] = 0
#     l_i = np.max(para_lmin, axis=1)

#     n_opt, n_mach = para_h.shape
#     if para_a.shape != (n_opt, n_opt, n_mach):
#         para_a = np.einsum("mij->ijm", para_a)
#     # eq. (19)
#     # para_a[selected_idx[:, 0], :, selected_idx[:, 1]] = 0
#     para_a[para_a == -np.inf] = 0
#     a_i = np.max(para_a, axis=(1, 2))
#     print(a_i)

#     # eq. (20)
#     l_a_max = [max(l_element, a_element) for l_element, a_element in zip(l_i, a_i)]
#     big_m = np.max(p_i + np.array(l_a_max))

#     return big_m

# %% [markdown]
# ## Debugging the Original MILP, FJSS3

# %%
# start_time = time.time()

if para_a.shape != (n_opt, n_opt, n_mach):
    para_a = np.einsum("mij->ijm", para_a)

fjss3 = FJSS3(
    operations=operations,
    machines=machines,
    para_p=para_p,
    para_a=para_a,
    para_w=para_w,
    para_h=para_h,
    para_delta=para_delta,
    para_mach_capacity=para_mach_capacity,
    para_lmin=para_lmin,
    para_lmax=para_lmax,
    precedence=None,
    model_string=None,
    inf_milp=infinity,
    num_workers=4,
    verbose=True,
    big_m=None,
)
fjss3.build_model_gurobi()
fjss3.solve_gurobi()
# running_time = time.time() - start_time

# using get_m_value_old works

# using get_m_value_runzhong does not work, big_m=374
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706218237.046878  632644 environment.cc:405] Found the Gurobi library in '/home/fwmeng/softs/gurobi1003/linux64/lib/libgurobi100.so.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-15
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07
# Set parameter OptimalityTol to value 1e-07
# Set parameter Presolve to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: AMD Ryzen Threadripper PRO 3995WX 64-Cores, instruction set [SSE2|AVX|AVX2]
# Thread count: 64 physical cores, 128 logical processors, using up to 32 threads
#
# Optimize a model with 10080 rows, 2961 columns and 50711 nonzeros
# Model fingerprint: 0x418231a5
# Variable types: 41 continuous, 2920 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 1684 rows and 2378 columns
# Presolve time: 0.09s
# Presolved: 8396 rows, 583 columns, 40034 nonzeros
# Variable types: 41 continuous, 542 integer (542 binary)
#
# Root relaxation: objective 6.980000e+02, 156 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  698.00000    0    3          -  698.00000      -     -    0s
#      0     0  698.00000    0    3          -  698.00000      -     -    0s
#      0     0  698.00000    0    9          -  698.00000      -     -    0s
#      0     0  698.00000    0    7          -  698.00000      -     -    0s
#      0     0  698.00000    0    4          -  698.00000      -     -    0s
#      0     0  698.00000    0    4          -  698.00000      -     -    0s
#      0     0  698.00000    0    3          -  698.00000      -     -    0s
#      0     0  698.00000    0    5          -  698.00000      -     -    0s
#      0     0  698.00000    0    3          -  698.00000      -     -    0s
#      0     0  698.00000    0    6          -  698.00000      -     -    0s
#      0     0 1.000e+100    0    6          - infeasible      -     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 15
#   RLT: 2
#
# Explored 1 nodes (762 simplex iterations) in 0.63 seconds (0.76 work units)
# Thread count was 32 (of 128 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# No solution found.

# %%
print(f"big_m = {fjss3.big_m}")
# Out:
# big_m = 374.0

# %%
# get_m_value(para_p=para_p, para_h=para_h, para_lmin=para_lmin, para_a=para_a)

# %%
# # eq. (20) adapted
# big_m = np.sum(p_i) + np.max([l_i.max(), a_i.max()])

# big_m

# %%
# TODO: fix this

# # start_time = time.time()
# fjss4 = FJSS4(
#     operations=operations,
#     machines=machines,
#     para_p=para_p,
#     para_a=para_a,
#     para_w=para_w,
#     para_h=para_h,
#     para_delta=para_delta,
#     para_mach_capacity=para_mach_capacity,
#     para_lmin=para_lmin,
#     para_lmax=para_lmax,
#     precedence=None,
#     model_string=None,
#     inf_milp=infinity,
#     num_workers=4,
#     verbose=True,
# )
# fjss4.build_model_gurobi()
# fjss4.solve_gurobi()
# # running_time = time.time() - start_time

# %%
# fjss4.model.computeIIS()

# %%
from checking_constraints import check_constraints_milp, check_constraints_cp

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_values(var):
    return var.solution_value()


v_get_values = np.vectorize(get_values)

var_y = v_get_values(fjss3.var_y)
var_s = v_get_values(fjss3.var_s)
var_c = v_get_values(fjss3.var_c)
var_c_max = fjss3.var_c_max
var_x = v_get_values(fjss3.var_x)
var_z = v_get_values(fjss3.var_z)

# check_constraints_cp(
#     var_y=var_y,
#     var_s=var_s,
#     var_c=var_c,
#     var_c_max=var_c_max,
#     var_u=None,
#     operations=operations,
#     machines=machines,
#     para_p=para_p,
#     para_a=para_a,
#     para_w=para_w,
#     para_h=para_h,
#     para_delta=para_delta,
#     para_mach_capacity=para_mach_capacity,
#     para_lmin=para_lmin,
#     para_lmax=para_lmax,
#     num_t=None,
# )
# Out:
# E0000 00:00:1706218238.160156  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161178  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161192  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161196  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161198  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161201  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161203  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161206  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161209  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161211  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161213  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161215  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161217  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161219  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161221  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161223  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161225  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161227  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161229  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161231  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161233  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161235  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161237  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161239  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161241  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161243  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161245  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161247  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161250  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161252  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161254  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161258  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161260  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161262  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161264  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161266  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161268  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161270  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161272  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161274  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161275  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161277  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161279  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161281  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161283  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161285  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161287  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161289  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161291  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161293  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161295  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161297  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161299  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161301  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161303  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161305  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161307  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161309  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161311  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161313  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161316  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161318  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161320  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161322  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161324  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161326  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161328  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161331  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161332  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161334  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161336  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161338  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161340  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161342  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161344  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161346  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161348  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161350  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161352  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161354  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161356  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161358  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161360  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161362  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161364  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161366  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161368  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161370  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161371  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161375  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161377  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161379  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161381  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161383  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161385  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161387  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161390  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161391  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161393  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161395  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161397  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161399  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161401  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161403  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161405  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161407  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161409  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161411  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161413  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161415  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161417  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161419  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161421  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161422  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161424  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161426  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161428  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161430  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161433  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161434  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161436  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161497  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161510  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161513  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161515  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161517  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161519  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161521  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161523  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161525  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161527  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161528  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161530  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161532  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161534  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161536  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161538  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161540  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161542  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161543  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161545  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161547  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161579  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161590  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161592  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161594  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161596  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161600  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161602  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161604  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161606  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161607  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161609  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161611  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161613  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161615  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161617  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161619  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161620  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161622  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161624  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161626  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161628  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161672  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161686  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161689  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161691  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161693  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161695  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161697  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161699  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161700  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161702  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161704  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161706  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161708  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161711  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161713  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161715  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161717  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161719  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161721  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161723  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161725  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161727  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161729  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161731  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161733  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161734  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161736  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161738  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161740  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161742  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161744  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161745  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161747  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161749  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161751  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161753  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161755  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161756  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161758  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161760  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161762  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161764  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161767  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161769  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161771  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161773  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161775  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161776  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161778  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161780  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161782  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161784  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161786  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161788  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161789  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161791  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161793  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161795  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161797  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161799  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161801  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161803  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161805  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161807  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161809  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161810  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161812  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161814  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161816  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161818  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161820  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161822  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161824  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161826  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161828  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161830  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161832  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161834  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161836  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161838  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161840  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161841  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161843  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161845  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161847  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161849  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161851  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161852  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161854  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161856  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161858  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161860  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161862  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161864  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161865  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161867  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161869  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161871  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161873  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161875  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161878  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161879  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161881  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161883  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161885  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161887  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161889  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161891  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161893  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161894  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161896  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161898  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161901  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161903  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161905  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161907  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161909  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161910  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161912  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161914  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161916  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161918  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161920  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161922  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161924  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161925  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161927  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161929  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161931  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161934  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161936  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161938  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161940  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161942  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161944  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161946  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161948  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161950  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161952  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161954  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161956  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161958  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161960  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161961  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161963  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161965  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161967  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161969  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161971  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161973  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161975  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161977  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161979  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161981  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161983  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161985  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161987  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161989  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161992  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161994  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161996  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161997  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.161999  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162001  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162003  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162005  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162007  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162009  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162011  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162013  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162015  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162017  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162019  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162021  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162022  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162024  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162026  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162028  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162030  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162032  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162034  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162036  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162038  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162040  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162042  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162044  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162046  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# ...
# E0000 00:00:1706218238.162075  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162077  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162078  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162080  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162082  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162084  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162086  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162088  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162090  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162092  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162094  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162096  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162097  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162099  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162101  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162103  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162106  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162108  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162110  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162111  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162113  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162115  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162117  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162119  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162121  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162123  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162124  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162126  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162128  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162130  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162132  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162134  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162136  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162138  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162140  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162142  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162143  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162145  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162147  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162149  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162151  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162153  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162155  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162157  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162159  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162162  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162163  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162166  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162167  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162169  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162171  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162173  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162175  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162177  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162179  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162181  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162182  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162184  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162186  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162188  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162190  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162192  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162194  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162196  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162198  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162200  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162202  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162204  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162206  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162208  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162210  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162212  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162214  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162216  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162218  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162220  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162222  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162224  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162226  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162228  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162229  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162231  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162233  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162235  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162237  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162239  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162241  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162243  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162245  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162247  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162249  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162251  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162253  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162254  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162256  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162258  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162260  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162262  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162264  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162266  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162268  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# E0000 00:00:1706218238.162270  632644 linear_solver.cc:2029] No solution exists. MPSolverInterface::result_status_ = MPSOLVER_INFEASIBLE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 11
#       9 var_c = v_get_values(fjss3.var_c)
#      10 var_c_max = fjss3.var_c_max
# ---> 11 var_x = v_get_values(fjss3.var_x)
#      12 var_z = v_get_values(fjss3.var_z)
#      14 # check_constraints_cp(
#      15 #     var_y=var_y,
#      16 #     var_s=var_s,
#    (...)
#      30 #     num_t=None,
#      31 # )
#
# File ~/.conda/envs/solver_py311/lib/python3.11/site-packages/numpy/lib/function_base.py:2372, in vectorize.__call__(self, *args, **kwargs)
#    2369     self._init_stage_2(*args, **kwargs)
#    2370     return self
# -> 2372 return self._call_as_normal(*args, **kwargs)
#
# File ~/.conda/envs/solver_py311/lib/python3.11/site-packages/numpy/lib/function_base.py:2365, in vectorize._call_as_normal(self, *args, **kwargs)
#    2362     vargs = [args[_i] for _i in inds]
#    2363     vargs.extend([kwargs[_n] for _n in names])
# -> 2365 return self._vectorize_call(func=func, args=vargs)
#
# File ~/.conda/envs/solver_py311/lib/python3.11/site-packages/numpy/lib/function_base.py:2455, in vectorize._vectorize_call(self, func, args)
#    2452 # Convert args to object arrays first
#    2453 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2455 outputs = ufunc(*inputs)
#    2457 if ufunc.nout == 1:
#    2458     res = asanyarray(outputs, dtype=otypes[0])
#
# Cell In[14], line 2, in get_values(var)
#       1 def get_values(var):
# ----> 2     return var.solution_value()
#
# File ~/.conda/envs/solver_py311/lib/python3.11/site-packages/ortools/linear_solver/pywraplp.py:662, in Variable.solution_value(self)
#     654 def solution_value(self):
#     655     r"""
#     656     Returns the value of the variable in the current solution.
#     657
#    (...)
#     660     automatically rounds it to the nearest integer; see: man 3 round).
#     661     """
# --> 662     return _pywraplp.Variable_solution_value(self)
#
# KeyboardInterrupt:

# %%
para_a[:, :, :] = -infinity

big_m = fjss3.big_m

check_constraints_milp(
    var_y=var_y,
    var_s=var_s,
    var_c=var_c,
    var_c_max=var_c_max,
    operations=operations,
    machines=machines,
    para_p=fjss3.para_p,
    para_a=fjss3.para_a,
    para_w=fjss3.para_w,
    para_h=fjss3.para_h,
    para_delta=fjss3.para_delta,
    para_mach_capacity=fjss3.para_mach_capacity,
    para_lmin=fjss3.para_lmin,
    para_lmax=fjss3.para_lmax,
    big_m=fjss3.big_m,
    var_x=var_x,
    var_z=var_z,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 21
#       1 para_a[:, :, :] = -infinity
#       3 big_m = fjss3.big_m
#       5 check_constraints_milp(
#       6     var_y=var_y,
#       7     var_s=var_s,
#       8     var_c=var_c,
#       9     var_c_max=var_c_max,
#      10     operations=operations,
#      11     machines=machines,
#      12     para_p=fjss3.para_p,
#      13     para_a=fjss3.para_a,
#      14     para_w=fjss3.para_w,
#      15     para_h=fjss3.para_h,
#      16     para_delta=fjss3.para_delta,
#      17     para_mach_capacity=fjss3.para_mach_capacity,
#      18     para_lmin=fjss3.para_lmin,
#      19     para_lmax=fjss3.para_lmax,
#      20     big_m=fjss3.big_m,
# ---> 21     var_x=var_x,
#      22     var_z=var_z,
#      23 )
#
# NameError: name 'var_x' is not defined

# %%
big_m
# Out:
# 1000050.0

# %%
n_opt, n_mach, operation_data, machine_data = parse_data("gfjsp_10_5_1.txt")

# %%
para_delta
# Out:
# array([1, 1, 1, 1, 1, 1], dtype=object)

# %%
    for m in range(n_mach):
        for idx_setup, setup_data in enumerate(machine_data[str(m)]["setup_data"][0]):
            print(setup_data[2])
# Out:
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# -inf
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# -inf
# -inf
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# 15.0
# -inf
# 15.0
# 15.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
